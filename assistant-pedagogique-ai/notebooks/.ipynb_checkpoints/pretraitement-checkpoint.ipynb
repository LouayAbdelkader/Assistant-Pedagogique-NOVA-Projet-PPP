# %% [markdown]
# # Objectif
# Notre objectif dans ce notebook est de transformer les données brut en PPT en une structure JSON bien claire et efficace à utiliser ultérieurement.

# %%
# structure finale voulue
# cette variable est à titre d'exemple, elle va s'écraser par la suite
course = {
    "course_name" : "Traitement du signal",
    "course_plan" : [
        {"chap_id" : 0, "chap_name" : "Introduction"},
        {"chap_id" : 1, "chap_name" : "Représentation et analyse temporelle des signaux"},
        {"chap_id" : 2, "chap_name" : "Systèmes linéaires continus"}
    ],
    "chapters" : [
        {
            "chap_id" : 0,
            "chap_name" : "Introduction",
            "content" : []
        },
        {
            "chap_id" : 1,
            "chap_name" : "Représentation temporelle des signaux",
            "content" : [
                {
                    "slide_id" : 23,
                    "section" : "Les différentes classes de signaux",
                    "categories" : {
                        "definition" : ["on definit .."],
                        "formula" : [
                                {
                                    "formula_id": 1,
                                    "type": "OMML",
                                    "extractable": True,
                                    "raw_text": "la formule ici"
                                }
                        ]
                    },
                    "notions" : ["Différents critères de classification"],
                    "slide_content" : 'Différents critères de classification :\n'
                                '\uf0a7 Nombre de variables ;\n'
                                '\uf0a7 Signaux réels / complexes ;\n'
                                '\uf0a7 Déterministes / aléatoires ;\n'
                                '\uf0a7 Continus / discrets ;\n'
                                '.\n'
                                '\uf0a7 Classification énergétique\n'
                                '23'
                },
                {
                    "slide_id" : 24,
                    "section" : "1- Classification en fonction du nombre de variables",
                    "categories" : {},
                    "notions" : [],
                    "slide_content" : 'Exemple de signal N. Variable (s) Type de signal'
                                'Tension électrique V(t) 1 monodimensionnel'
                                'Image f(x,y) 2 bidimensionnel'
                                'Vidéo I(x,y,t) 3 tridimensionnel'
                                '. . .'
                                '. . .'
                                '. . .'
                                'Onde e.m u(x,y,z,t) N multidimensionnel'
                                '24'
                }
            ]
        },
        {
        "chap_id" : 2,
        "chap_name" : "Systèmes linéaires continus\nDéfinition et caractérisation",
        "content" : []
        }
    ]
}

# lorsqu'on commence la partie category, on doit faire une modification sur la variable "course"
categories = ["definition", "exemple", "formula", "remark"]

# %% [markdown]
# # Initialisations
# Pour simplifier, supposons maintenant que :
# - le plan est fixé manuellement
# - l'introduction est ignorée (l'introduction est le chapitre 0)
# - **tous les fichiers `.pptx` du dossier `ppt` sont traités** : un document ppt = un chapitre (trié par nom de fichier)

# %%
from pprint import pprint
import os
import glob

# Dossier contenant les .pptx
PPT_DIR = "../data/1-ppt/"

# récupérer tous les vrais .pptx
PPT_FILES = sorted([
    f for f in glob.glob(os.path.join(PPT_DIR, "*.pptx"))
    if not os.path.basename(f).startswith("~$")
])

print(f"{len(PPT_FILES)} fichier(s) trouve(s) dans '{PPT_DIR}' :")

for i, path in enumerate(PPT_FILES, start=1):
    print(f"  Chapitre {i} -> {os.path.basename(path)}")

# Initialisation du cours
course = {}
course["course_name"] = "Traitement du signal"

course["course_plan"] = [
    {"chap_id": 0, "chap_name": "Introduction"}
]

course["chapters"] = []

print("\nInitialisation OK.")
# Out:
# 2 fichier(s) trouve(s) dans '../data/1-ppt/' :
#   Chapitre 1 -> Cours_TS_Chap1.pptx
#   Chapitre 2 -> Cours_TS_Chap2.pptx
#
# Initialisation OK.

# %% [markdown]
# # Extraction du nom de chapitre
# Pour structurer le chapitre 1 (= le dictionnaire course["chapters"][0]), on commence par extraire le **nom du chapitre** (extrait du slide 1 du ppt) :

# %%
import os
from pptx import Presentation

def extract_chapter_name(first_slide_text, ppt_path=""):
    lines = first_slide_text.split("\n")
    # Nettoyer lignes vides
    lines = [line.strip() for line in lines if line.strip()]
    # Enlever "Chapitre ..."
    if lines and "chapitre" in lines[0].lower():
        lines = lines[1:]
    # Enlever numero de slide (ex: "22")
    if lines and lines[-1].isdigit():
        lines = lines[:-1]
    # Prendre premiere ligne
    if lines:
        return lines[0]
    # Fallback -> nom du fichier ppt
    return os.path.basename(ppt_path).replace(".pptx", "")
    
# ── Parcours des chapitres ─────────────────────────────
course["chapters"]=[]
for i, file in enumerate(PPT_FILES, start=1):
    prs = Presentation(file)

    # première slide
    first_slide = prs.slides[0]

    # texte de la slide
    first_slide_text = "\n".join(
        shape.text
        for shape in first_slide.shapes
        if shape.has_text_frame
    )

    # nom du chapitre
    chapter_name = extract_chapter_name(first_slide_text, file)

    # sauvegarde
    chapter = {
        "chap_id": i,
        "chap_name": chapter_name,
        "content": []
        
    }

    course["chapters"].append(chapter)

    # affichage
    print(f"Chapitre {i} : {chapter_name}")


# ── Résultat final ────────────────────────────────────

print("\nListe des chapitres :")
pprint(course["chapters"])
# Out:
# Chapitre 1 : Représentation temporelle des signaux
# Chapitre 2 : Systèmes linéaires continus
#
# Liste des chapitres :
# [{'chap_id': 1,
#   'chap_name': 'Représentation temporelle des signaux',
#   'content': []},
#  {'chap_id': 2, 'chap_name': 'Systèmes linéaires continus', 'content': []}]

# %% [markdown]
# # Extraction de la section d'un slide
# On passe au contenu du chapitre, qui est une liste de slides.
# On commence par extraire le **titre/section** de chaque slide.
#
# *Remarque :* L’extraction des sections a posé des difficultés en raison de titres non correctement détectés. Une **étape manuelle** a donc été nécessaire, consistant à ajuster le layout des slides dans PowerPoint afin de définir explicitement les titres.

# %%
import re
from pptx import Presentation

def clean_section_title(title):
    """
    Nettoie le titre :
    - supprime les chiffres au début
    - supprime les tirets/points après le numéro
    - supprime les espaces inutiles
    """

    if not title:
        return ""

    # enlever espaces début/fin
    title = title.strip()

    # supprimer : 1-  / 2. / 3 ) / 4 :
    title = re.sub(r'^\d+\s*[-.):]*\s*', '', title)

    # supprimer espaces multiples
    title = re.sub(r'\s+', ' ', title)

    return title.strip()


def extract_slide_section(slide):

    # récupérer le vrai titre du slide
    if slide.shapes.title and slide.shapes.title.text.strip():
        section = slide.shapes.title.text.strip()

    else:
        # fallback → première ligne texte trouvée
        all_text = []

        for shape in slide.shapes:
            if shape.has_text_frame:
                for p in shape.text_frame.paragraphs:
                    txt = p.text.strip()

                    if txt:
                        all_text.append(txt)

        section = all_text[0] if all_text else ""

    # nettoyage
    section = clean_section_title(section)

    return section


for file in PPT_FILES:

    prs = Presentation(file)

    print(f"\n========== {file} ==========\n")

    for i, slide in enumerate(prs.slides):

        section = extract_slide_section(slide)

        print(f"Slide {i+1} section: {section}")
        print("------")
# Out:
# ========== ../data/1-ppt\Cours_TS_Chap1.pptx ==========
#
# Slide 1 section: Chapitre 1
# ------
# Slide 2 section: Les différentes classes de signaux
# ------
# Slide 3 section: Classification en fonction du nombre de variables
# ------
# Slide 4 section: Signaux réels / complexes
# ------
# Slide 5 section: Signaux déterministes / aléatoires
# ------
# Slide 6 section: Signaux déterministes / aléatoires
# ------
# Slide 7 section: Signaux déterministes / aléatoires
# ------
# Slide 8 section: Signaux continus / discrets
# ------
# Slide 9 section: Signaux continus / discrets
# ------
# Slide 10 section: Signaux continus / discrets
# ------
# Slide 11 section: Signaux continus / discrets
# ------
# Slide 12 section: Signaux continus / discrets
# ------
# Slide 13 section: Signaux continus / discrets
# ------
# Slide 14 section: Classification énergétique
# ------
# Slide 15 section: Classification énergétique
# ------
# Slide 16 section: Classification énergétique
# ------
# Slide 17 section: Classification énergétique
# ------
# Slide 18 section: Classification énergétique
# ------
# Slide 19 section: Classification énergétique
# ------
# Slide 20 section: Classification énergétique
# ------
# Slide 21 section: Classification énergétique
# ------
# Slide 22 section: Propriétés d’un signal
# ------
# Slide 23 section: Propriétés d’un signal
# ------
# Slide 24 section: Propriétés d’un signal
# ------
# Slide 25 section: Propriétés d’un signal
# ------
# Slide 26 section: Propriétés d’un signal
# ------
# Slide 27 section: Propriétés d’un signal
# ------
# Slide 28 section: Propriétés d’un signal
# ------
# Slide 29 section: Quelques signaux élémentaires
# ------
# Slide 30 section: Quelques signaux élémentaires
# ------
# Slide 31 section: Quelques signaux élémentaires
# ------
# Slide 32 section: Quelques signaux élémentaires
# ------
# Slide 33 section: Quelques signaux élémentaires
# ------
# Slide 34 section: Quelques signaux élémentaires
# ------
# Slide 35 section: Quelques signaux élémentaires
# ------
# Slide 36 section: La distribution de Dirac
# ------
# Slide 37 section: La distribution de Dirac
# ------
# Slide 38 section: La distribution de Dirac
# ------
# Slide 39 section: La distribution de Dirac
# ------
# Slide 40 section: Peigne de Dirac
# ------
# Slide 41 section: Peigne de Dirac
# ------
# Slide 42 section: Conclusion
# ------
# Slide 43 section: Remarques
# ------
# Slide 44 section: Remarques
# ------
#
# ========== ../data/1-ppt\Cours_TS_Chap2.pptx ==========
#
# Slide 1 section: Chapitre 2
# ------
# Slide 2 section: Contenu du cours
# ------
# Slide 3 section: Introduction
# ------
# Slide 4 section: Définition
# ------
# Slide 5 section: Définition
# ------
# Slide 6 section: Classification des systèmes
# ------
# Slide 7 section: Classification des systèmes
# ------
# Slide 8 section: Classification des systèmes
# ------
# Slide 9 section: Classification des systèmes
# ------
# Slide 10 section: Exemples
# ------
# Slide 11 section: Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Slide 12 section: Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Slide 13 section: Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Slide 14 section: Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Slide 15 section: Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Slide 16 section: Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Slide 17 section: Caractérisation d’un système LTI
# ------
# Slide 18 section: Caractérisation d’un système LTI
# ------
# Slide 19 section: Caractérisation d’un système LTI
# ------
# Slide 20 section: Caractérisation d’un système LTI
# ------
# Slide 21 section: Caractérisation d’un système LTI
# ------
# Slide 22 section: Produit de convolution
# ------
# Slide 23 section: Produit de convolution : interprétation
# ------
# Slide 24 section: Produit de convolution : interprétation graphique
# ------
# Slide 25 section: Produit de convolution : Exemple
# ------
# Slide 26 section: Produit de convolution : Exemple
# ------
# Slide 27 section: Produit de convolution : Propriétés
# ------
# Slide 28 section: Produit de convolution : Propriétés
# ------
# Slide 29 section: Réponse d’un système LTI à une entrée quelconque
# ------
# Slide 30 section: Réponse d’un système LTI à une entrée quelconque
# ------
# Slide 31 section: Réponse d’un système LTI à une entrée quelconque
# ------
# Slide 32 section: Stabilité et réponse impulsionnelle
# ------
# Slide 33 section: Causalité et réponse impulsionnelle
# ------

# %% [markdown]
# # Extraction du contenu d'un slide
# Puis on extrait le **contenu du slide** :

# %%
from pptx import Presentation
from pptx.enum.shapes import PP_PLACEHOLDER
from lxml import etree

MC_NS   = "http://schemas.openxmlformats.org/markup-compatibility/2006"
DML_NS  = "http://schemas.openxmlformats.org/drawingml/2006/main"
MATH_NS = "http://schemas.openxmlformats.org/officeDocument/2006/math"

# ── Équations OOXML ──────────────────────────────────────────────────────────

def extract_math(omath_el):
    tokens = []

    def walk(el):
        tag = etree.QName(el.tag).localname
        if tag == 't':
            if el.text: tokens.append(el.text)
        elif tag == 'f':
            num = el.find(f'{{{MATH_NS}}}num')
            den = el.find(f'{{{MATH_NS}}}den')
            n = "".join(t.text or "" for t in num.iter(f'{{{MATH_NS}}}t')) if num is not None else ""
            d = "".join(t.text or "" for t in den.iter(f'{{{MATH_NS}}}t')) if den is not None else ""
            tokens.append(f"({n}/{d})")
        elif tag == 'sSup':
            base = el.find(f'{{{MATH_NS}}}e')
            sup  = el.find(f'{{{MATH_NS}}}sup')
            b = "".join(t.text or "" for t in base.iter(f'{{{MATH_NS}}}t')) if base is not None else ""
            s = "".join(t.text or "" for t in sup.iter(f'{{{MATH_NS}}}t'))  if sup  is not None else ""
            tokens.append(f"{b}^{s}")
        elif tag == 'sSub':
            base = el.find(f'{{{MATH_NS}}}e')
            sub  = el.find(f'{{{MATH_NS}}}sub')
            b = "".join(t.text or "" for t in base.iter(f'{{{MATH_NS}}}t')) if base is not None else ""
            s = "".join(t.text or "" for t in sub.iter(f'{{{MATH_NS}}}t'))  if sub  is not None else ""
            tokens.append(f"{b}_{s}")
        elif tag == 'rad':
            deg  = el.find(f'{{{MATH_NS}}}deg')
            base = el.find(f'{{{MATH_NS}}}e')
            d = "".join(t.text or "" for t in deg.iter(f'{{{MATH_NS}}}t'))  if deg  is not None else ""
            b = "".join(t.text or "" for t in base.iter(f'{{{MATH_NS}}}t')) if base is not None else ""
            tokens.append(f"√{d}({b})" if d.strip() else f"√({b})")
        elif tag == 'd':
            tokens.append("(")
            for child in el:
                if etree.QName(child.tag).localname == 'e': walk(child)
            tokens.append(")")
        elif tag not in ('rPr','mPr','dPr','fPr','sSupPr','sSubPr',
                         'radPr','ctrlPr','argPr','groupChrPr'):
            for child in el: walk(child)

    walk(omath_el)
    return "".join(tokens)


# ── Paragraphe complet (runs + champs + équations) ───────────────────────────

def extract_paragraph_full(para_el, slide_number=None):
    parts = []
    for child in para_el:
        local = etree.QName(child.tag).localname
        if local == 'r':
            t = child.find(f'{{{DML_NS}}}t')
            if t is not None and t.text:
                parts.append(t.text)
        elif local == 'fld':
            fld_type = child.get('type', '')
            t = child.find(f'{{{DML_NS}}}t')
            if fld_type == 'slidenum':
                parts.append(str(slide_number) if slide_number is not None else '[SLIDE_NUM]')
            elif fld_type == 'datetime':
                parts.append(t.text if t is not None and t.text else '[DATE]')
            else:
                parts.append(t.text if t is not None and t.text else f'[FLD:{fld_type}]')
        elif local == 'm':
            omath = child.find(f'{{{MATH_NS}}}oMath')
            if omath is not None:
                parts.append(f"[EQ: {extract_math(omath)}]")
    return "".join(parts)
    
def extract_slide_content(slide, section, slide_number):
    seen   = set()
    blocks = []

    def add(text):
        text = text.strip()
        if (text
                and text != section
                and text not in seen
                and text != str(slide_number)):   # ← exclure le numéro de slide
            seen.add(text)
            blocks.append(text)

    # 1. Shapes normales
    for shape in slide.shapes:
        if not shape.has_text_frame:
            continue
        if shape.is_placeholder:
            ph_type = shape.placeholder_format.type
            # Ignorer titre ET numéro de slide
            if ph_type in {PP_PLACEHOLDER.TITLE,
                           PP_PLACEHOLDER.CENTER_TITLE,
                           PP_PLACEHOLDER.SLIDE_NUMBER}:   # ← ignorer le placeholder entier
                continue

        for para in shape.text_frame._txBody.findall(f'{{{DML_NS}}}p'):
            line = extract_paragraph_full(para, slide_number)
            add(line)

    # 2. AlternateContent
    for child in slide.shapes._spTree:
        if child.tag != f'{{{MC_NS}}}AlternateContent':
            continue
        choice = child.find(f'{{{MC_NS}}}Choice')
        source = choice if choice is not None else child.find(f'{{{MC_NS}}}Fallback')
        if source is None:
            continue
        for para in source.findall(f'.//{{{DML_NS}}}p'):
            line = extract_paragraph_full(para, slide_number)
            add(line)

    return "\n".join(blocks)


# ── Point d'entrée ───────────────────────────────────────────────────────────

for i, file in enumerate(PPT_FILES, start=1):
    prs = Presentation(file)
    print(f"\n========== {file} ==========\n")
    for i, slide in enumerate(prs.slides):
        slide_number = i + 1
        section      = extract_slide_section(slide)
        content      = extract_slide_content(slide, section, slide_number)
    
        print(f"Slide {slide_number} — section : {section}")
        print("------")
        if content:                          # ← n'afficher que si non vide
            print(f"Content:\n{content}")
            print("======")
# Out:
# ========== ../data/1-ppt\Cours_TS_Chap1.pptx ==========
#
# Slide 1 — section : Chapitre 1
# ------
# Content:
# Représentation temporelle des signaux
# ======
# Slide 2 — section : Les différentes classes de signaux
# ------
# Content:
# Différents critères de classification :
# Nombre de variables ;
# Signaux réels / complexes ;
# Déterministes / aléatoires ;
# Continus / discrets ;
# Classification énergétique.
# ======
# Slide 3 — section : Classification en fonction du nombre de variables
# ------
# Slide 4 — section : Signaux réels / complexes
# ------
# Content:
# signal réel  :    si   [EQ: 𝑥(𝑡)∈ℝ]
# signal complexe : si   [EQ: 𝑥(𝑡)∈ℂ]
# Notations usuelles:
# Nombre complexe  [EQ: 𝑗: 𝑗^2=−1]
# Si [EQ: 𝑥(𝑡)=𝑎(𝑡)+𝑗 𝑏(𝑡)]  :
# partie réelle : [EQ: 𝑅𝑒(𝑥(𝑡))=𝑎(𝑡)]
# partie imaginaire:  [EQ: 𝐼𝑚(𝑥(𝑡))=𝑏(𝑡)]
# module: [EQ: (𝑥(𝑡))=√(𝑎2𝑡+𝑏2𝑡)]
# argument: [EQ: 𝐴𝑟𝑔(𝑥(𝑡))=𝑎𝑟𝑐𝑡𝑎𝑛((𝑏(𝑡)/𝑎(𝑡)))]
# [EQ: 𝑥(𝑡)=(𝑥(𝑡))𝑒^𝑗𝐴𝑟𝑔𝑥𝑡]
# Complexe conjugué:   [EQ: 𝑥^∗(𝑡)=𝑎(𝑡)−𝑗 𝑏(𝑡)=(𝑥(𝑡))𝑒^−𝑗𝐴𝑟𝑔𝑥𝑡]
# ======
# Slide 5 — section : Signaux déterministes / aléatoires
# ------
# Content:
# Signaux déterministes (ou signaux certains): on connaît la valeur du signal quelque soit l’instant t .
# Leur évolution en fonction du temps peut être parfaitement modélisée par une fonction mathématique appropriée.
# On retrouve dans cette classe les signaux périodiques, les signaux non périodiques et les signaux transitoires:
# apériodiques 	           périodiques                transitoires
# ======
# Slide 6 — section : Signaux déterministes / aléatoires
# ------
# Content:
# Signaux aléatoires : l’évolution est imprévisible et non reproductible d’une expérience à l’autre.
# Exemple : le bruit
# Il faut faire appel à leurs propriétés statistiques pour les décrire (moyenne, variance, loi de probabilité,…).
# Si leurs propriétés statistiques sont invariantes dans le temps, on dit qu’ils sont  stationnaires.
# ======
# Slide 7 — section : Signaux déterministes / aléatoires
# ------
# Content:
# On a souvent:
# signal réel  = signal déterministe  +  signal aléatoire ( bruit)
# ======
# Slide 8 — section : Signaux continus / discrets
# ------
# Content:
# Il existe deux types de signaux temporels :
# Signaux à variable continue : [EQ: 𝑥(𝑡)   𝑎𝑣𝑒𝑐   𝑡 ∈ℝ]
# signal connu à chaque instant t
# Exemple : onde électromagnétique, signal électrique, ...
# Traitement analogique du signal
# Signaux à variable discrète:   [EQ: 𝑥_𝑛   𝑎𝑣𝑒𝑐    𝑛 ∈ℤ]
# signal connu uniquement à certains instants tn
# Exemple : cours de la bourse enregistré chaque heure, signal
# provenant d’un signal analogique que l’on a échantillonné
# Traitement numérique du signal
# ======
# Slide 9 — section : Signaux continus / discrets
# ------
# Content:
# Il existe deux types de signaux temporels :
# ======
# Slide 10 — section : Signaux continus / discrets
# ------
# Slide 11 — section : Signaux continus / discrets
# ------
# Slide 12 — section : Signaux continus / discrets
# ------
# Slide 13 — section : Signaux continus / discrets
# ------
# Content:
# Support temporel: On appelle support temporel, l’ensemble des temps [EQ: 𝑡] (ou des échantillons [EQ: 𝑛] si le signal est discret) pour lesquels le signal [EQ: 𝑥(𝑡) ](resp. [EQ: 𝑥_𝑛 ]) est défini et non nul.
# Cas continu. Si cet ensemble correspond à un intervalle ayant des limites hautes et basses, on dit que le support temporel est borné. Sinon, on dit qu’il est non borné.
# Cas discret. Si cet ensemble contient un nombre fini de valeurs, on dit que le support temporel est fini. Sinon, on dit qu’il est infini.
# Remarque : Dans la pratique, tous les signaux physiques observés sont à support fini ou à support borné.
# ======
# Slide 14 — section : Classification énergétique
# ------
# Content:
# Puissance instantanée:  Etant donné un signal continu x(t), on appelle puissance instantanée la quantité |x(t)|2
# ======
# Slide 15 — section : Classification énergétique
# ------
# Content:
# Energie totale: L’énergie totale Ex correspond à la somme de la puissance instantanée sur ℝ.
# ======
# Slide 16 — section : Classification énergétique
# ------
# Content:
# Puissance moyenne: La puissance moyenne (totale) Px correspond à la valeur moyenne de la puissance instantanée sur ℝ.
# Si le signal est à support temporel borné, sa puissance moyenne totale est donc nulle.
# ======
# Slide 17 — section : Classification énergétique
# ------
# Content:
# Si Ex < +∞, on dit que le signal est à énergie finie.
# En pratique, c’est le cas de tous les signaux physiquement réalisables.
# Un signal à énergie finie a une puissance moyenne totale nulle.
# Si Px < + ∞, on dit que le signal est à puissance finie.
# Bien que ces signaux n’existent pas dans le monde réel, ils sont utiles pour construire des modèles étudiables.
# Un signal de puissance moyenne totale non nulle est un signal  d’énergie infinie.
# ======
# Slide 18 — section : Classification énergétique
# ------
# Content:
# Cas des signaux périodiques:
# Un signal x(t) est dit périodique de période T0, si
# Exemple de signaux périodiques:  sinus et cosinus
# avec
# ======
# Slide 19 — section : Classification énergétique
# ------
# Content:
# Propriétés d’un signal périodique:
# Un signal périodique continu a nécessairement un support temporel non borné.
# Démonstration : le signal se répète toutes les périodes [EQ: 𝑇_0] une infinité de fois
# Si un signal continu est périodique de période [EQ: 𝑇_0] , alors il est aussi périodique de période [EQ: 𝑘.𝑇_0] avec [EQ: 𝑘∈ ℤ]
# Etant donné un signal périodique, on appelle période fondamentale et on note  [EQ: 𝑇_0], la plus petite période du signal strictement positive:
# ======
# Slide 20 — section : Classification énergétique
# ------
# Content:
# Cas des signaux périodiques
# On a déjà vu qu’un signal périodique se répliquait une infinité de fois, il est donc nécessairement d’énergie infinie.
# un signal [EQ: 𝑥(𝑡)] est périodique de période [EQ: 𝑇_0], alors sa puissance moyenne est définie par:
# ======
# Slide 21 — section : Classification énergétique
# ------
# Content:
# Les signaux à énergie finie
# -  les signaux transitoires
# -  les signaux à support temporal borné
# Les signaux à énergie infinie
# -  à puissance moyenne finie
# ex. les signaux périodiques
# -  à puissance moyenne infinie
# ex. la rampe  [EQ: 𝑥(𝑡)=𝑡]
# ======
# Slide 22 — section : Propriétés d’un signal
# ------
# Content:
# Causalité
# Un signal [EQ: 𝑥(𝑡)  ]est dit causal si et seulement si [EQ: 𝑥(𝑡)=0, ∀ 𝑡<0]
# Signal causal                                  signal non causal
# ======
# Slide 23 — section : Propriétés d’un signal
# ------
# Content:
# Parité
# Un signal [EQ: 𝑥(𝑡) ]est pair si [EQ: 𝑥(𝑡)=𝑥(−𝑡)]
# Un signal [EQ: 𝑥(𝑡) ]est impair si  [EQ: 𝑥(𝑡)=−𝑥(−𝑡)]
# ======
# Slide 24 — section : Propriétés d’un signal
# ------
# Content:
# Parité
# Tout signal réel [EQ: 𝑥(𝑡) ]quelconque peut s’écrire sous forme de la  somme de deux signaux : un signal pair et un signal impair :
# ======
# Slide 25 — section : Propriétés d’un signal
# ------
# Content:
# Transformations de la variable t
# Retournement:   symétrie par rapport à 0
# x(t) → x(-t)
# ======
# Slide 26 — section : Propriétés d’un signal
# ------
# Content:
# Transformations de la variable t
# Translation:   de t0
# x(t) → x(t - t0)   (décalage vers la droite)
# x(t) → x(t + t0)  (décalage vers la gauche)
# ======
# Slide 27 — section : Propriétés d’un signal
# ------
# Content:
# Transformations de la variable t
# Changement  d’échelle: x(t) → x(at)
# (a>1)   contraction
# (a<1)   dilatation
# Illustration: https://vincmazet.github.io/spetsi/dilatation.html
# ======
# Slide 28 — section : Propriétés d’un signal
# ------
# Content:
# Transformations de la variable t
# Changement  d’échelle: x(t) → x(at)
# Illustration: https://vincmazet.github.io/spetsi/dilatation.html
# ======
# Slide 29 — section : Quelques signaux élémentaires
# ------
# Content:
# Sinusoïde
# Illustration: https://vincmazet.github.io/spetsi/sinus.html
# ======
# Slide 30 — section : Quelques signaux élémentaires
# ------
# Content:
# Sinus Cardinal
# Ce signal joue un rôle important en traitement du signal
# Il apparaîtra naturellement quand nous allons calculer des transformées de Fourier
# ======
# Slide 31 — section : Quelques signaux élémentaires
# ------
# Content:
# Signal rectangulaire
# On l’appelle aussi signal porte. Il sert de fonction de fenêtrage élémentaire.
# ======
# Slide 32 — section : Quelques signaux élémentaires
# ------
# Content:
# Signal rectangulaire
# fenêtrage : si on prend un signal quelconque [EQ: 𝑥(𝑡) ]et qu’on le multiplie par un signal porte, cela revient à étudier le signal [EQ: 𝑥(𝑡) ]uniquement sur le support  [EQ: ((−𝑇/2), (𝑇/2))]  :
# ======
# Slide 33 — section : Quelques signaux élémentaires
# ------
# Content:
# Fonction triangulaire
# ======
# Slide 34 — section : Quelques signaux élémentaires
# ------
# Content:
# Fonction échelon unité (Heaviside )
# [EQ: Γ(𝑡)=(0    pour   𝑡<01    pour   𝑡≥0)]
# Par convention, on admet une valeur à l’origine[EQ:  Γ(𝑡)=1 ]pout t=0
# Cette fonction permet de rendre causal un signal [EQ: :  Γ(𝑡).  𝑥(𝑡) ] est nul si [EQ: 𝑡<0]
# ======
# Slide 35 — section : Quelques signaux élémentaires
# ------
# Content:
# Fonction signe
# Par défaut, on admet une valeur à l’origine, [EQ: 𝑠𝑔𝑛(𝑡)=1] pour [EQ: t=0]
# ======
# Slide 36 — section : La distribution de Dirac
# ------
# Content:
# L’Impulsion de Dirac est définie par:
# δ(t) ne peut pas être représentée graphiquement. On la schématise par le symbole
# Attention: le 1 marqué sur la flèche représente l’aire de cette impulsion et non l’hauteur de l’impulsion
# ======
# Slide 37 — section : La distribution de Dirac
# ------
# Content:
# Mathématiquement, l’impulsion de Dirac est caractérisée par:
# Une aire valant 1 :   [EQ: ∞+∞𝛿(𝑡)𝑑𝑡=1]
# Une valeur nulle sauf en 0 : [EQ: 𝛿(𝑡)=0,     ∀ 𝑡 ≠0]
# Dirac appliquée à une fonction : [EQ: 𝑥(𝑡).𝛿(𝑡)=𝑥(0).𝛿(𝑡)]
# ([EQ: ∞+∞𝑥(𝑡)𝛿(𝑡)𝑑𝑡=𝑥(0))]
# La distribution de Dirac est une fonction paire
# ======
# Slide 38 — section : La distribution de Dirac
# ------
# Content:
# Remarque 1: l’Impulsion de Dirac peut être vue comme une fonction porte dont la largeur T tendrait vers 0 et dont l’aire est égale à 1
# Illustration: https://vincmazet.github.io/spetsi/limite-dirac.html
# Remarque 2: : On peut considérer [EQ: 𝛿(𝑡) ]comme la dérivée de la fonction échelon
# ======
# Slide 39 — section : La distribution de Dirac
# ------
# Content:
# Dirac décalée de t0: [EQ:    𝛿(𝑡−𝑡_0) ]est telle que:
# -   [EQ: −∞+∞𝛿(𝑡−𝑡_0)dt=1]
# -  [EQ: 𝛿(𝑡−𝑡_0)=0     ∀ 𝑡 ≠𝑡_0]
# - [EQ:   𝑥(𝑡)𝛿(𝑡−𝑡_0)=𝑥(𝑡_0)𝛿(𝑡−𝑡_0)]
# ======
# Slide 40 — section : Peigne de Dirac
# ------
# Content:
# On appelle peigne de Dirac une somme infinie d’impulsions de Dirac régulièrement espacées de  [EQ: 𝑇] . Elle est définie par :
# [EQ: Ш_𝑇(𝑡)=𝑘=−∞+∞𝛿(𝑡−𝑘𝑇) ]
# [EQ: 𝑇] est la période du peigne.
# ======
# Slide 41 — section : Peigne de Dirac
# ------
# Content:
# Cette fonction permet de modéliser de façon théorique le processus d’échantillonnage
# ======
# Slide 42 — section : Conclusion
# ------
# Content:
# Etant donné un signal, on sait maintenant le caractériser de la façon suivante:
# ◮ Continu / Discret ?
# ◮ Support temporel borné/fini / non borné/infini ?
# ◮ Périodique ou pas ? Période fondamentale ?
# ◮ Energie finie / Puissance finie ?
# ◮ Deux cas courants :
# Signaux périodiques : énergie totale infinie, puissance moyenne totale finie
# Signaux à support temporel borné : énergie totale finie, puissance moyenne totale nulle
# ======
# Slide 43 — section : Remarques
# ------
# Content:
# Un signal expérimental s(t) est généralement un signal physique délivré par un capteur ou un appareil de mesure et varie en fonction du temps. Il doit être physiquement réalisable et répondre à un ensemble de contraintes :
# à énergie bornée,
# à amplitude bornée,
# continu,
# causal, défini sur ℝ+,
# à support borné (de durée limitée ou finie)
# ======
# Slide 44 — section : Remarques
# ------
# Content:
# Sur le plan théorique, un signal est représenté par une fonction réelle ou complexe qui permet son étude de façon plus aisée. Ainsi les modèles utilisés possèdent des caractéristiques différentes des signaux expérimentaux :
# à énergie théorique infinie,
# à amplitude non bornée,
# ayant des  discontinuités,
# définie sur ℝ ou ℂ,
# à support non borné   (observé durant un temps infini)
# ======
#
# ========== ../data/1-ppt\Cours_TS_Chap2.pptx ==========
#
# Slide 1 — section : Chapitre 2
# ------
# Content:
# Systèmes linéaires continus
# Définition et caractérisation
# ======
# Slide 2 — section : Contenu du cours
# ------
# Content:
# Introduction
# Définition d'un système
# Classification des systèmes
# Caractérisation temporelle: Réponse d'un système LTI à une
# entrée
# Réponse impulsionnelle
# Notion de convolution
# Réponse à une entrée quelconque
# ======
# Slide 3 — section : Introduction
# ------
# Content:
# Exemples de systèmes
# ======
# Slide 4 — section : Définition
# ------
# Content:
# Un système est un ensemble d'éléments fonctionnels interagissant entre eux et qui établit un lien de cause à effet entre ses signaux d'entrées et ses signaux de sortie
# ======
# Slide 5 — section : Définition
# ------
# Content:
# Un système est une entité qui transforme un signal d’ entrée en un signal de sortie.
# ======
# Slide 6 — section : Classification des systèmes
# ------
# Content:
# Systèmes mono-variable et multi-variable
# Mono-variable : système à une entrée et une sortie
# Multi-variable : nombre d'entrées + nombre de sorties > 2
# Linéarité
# S[EQ: i 𝑥(𝑡)=𝑎_1𝑥_1(𝑡)+𝑎_2𝑥_2(𝑡)] alors[EQ:  𝑦(𝑡)=𝑎_1𝑆(𝑥_1(𝑡))+𝑎_2𝑆(𝑥_2(𝑡))]
# ======
# Slide 7 — section : Classification des systèmes
# ------
# Content:
# Causalité
# La réponse du système ne peut pas se produire avant l'excitation qui l'engendre
# Si [EQ: 𝑥(𝑡)=0] pour  [EQ: 𝑡<0]   alors     [EQ: y(𝑡)=𝑆(𝑥(𝑡))=0  ] pour [EQ: 𝑡<0]
# ======
# Slide 8 — section : Classification des systèmes
# ------
# Content:
# Invariance temporelle
# Un décalage temporel en entrée induit le même décalage en sortie.
# La réponse du système est invariante par translation dans le temps.
# Si [EQ: y(𝑡)=𝑆(𝑥(𝑡)) ]    alors     [EQ: y(𝑡−𝑡_0)=𝑆(𝑥(𝑡−𝑡_0))]
# ======
# Slide 9 — section : Classification des systèmes
# ------
# Content:
# Stabilité
# Un système est dit stable si en réponse à une entrée bornée, sa sortie est bornée.
# Système qui, perturbé, revient à son état initial après disparition de la perturbation
# ======
# Slide 10 — section : Exemples
# ------
# Content:
# Tachymètre
# Entrée : Vitesse d'un véhicule v(t)
# Sortie : Position angulaire de l'aiguille  θ (t)
# Propriétés : linéaire, causal, invariant
# Exemple de système
# non invariant :  y(t) = t.x(t); parcmètre (le tarif dépend de l'heure)
# Dans la suite, on étudiera les systèmes mono-variables continus linéaires à temps invariant (systèmes LTI)
# ======
# Slide 11 — section : Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Content:
# Linéarité
# ======
# Slide 12 — section : Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Content:
# Linéarité
# ======
# Slide 13 — section : Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Content:
# Linéarité
# ======
# Slide 14 — section : Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Content:
# Invariance temporelle
# ======
# Slide 15 — section : Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Content:
# Exemple de système variant temporellement
# ======
# Slide 16 — section : Les systèmes Linéaires Invariants Temporellement SLIT
# ------
# Content:
# Exemple de système variant temporellement
# ======
# Slide 17 — section : Caractérisation d’un système LTI
# ------
# Content:
# Relation entrée/sortie
# La plus courante: équation différentielle linéaire à coefficients constants
# Avec
# Caractérisation complète du système par la connaissance des coefficients (ai) et (bi)
# Sortie y(t) calculable par la connaissance de x(t)
# ======
# Slide 18 — section : Caractérisation d’un système LTI
# ------
# Content:
# Relation entrée/sortie
# La plus courante: équation différentielle linéaire à coefficients constants
# Avec
# Exemple:
# ======
# Slide 19 — section : Caractérisation d’un système LTI
# ------
# Content:
# Réponse impulsionnelle
# La réponse impulsionnelle h(t) d'un système S est sa réponse à une entrée sous forme d‘une impulsion de Dirac
# ======
# Slide 20 — section : Caractérisation d’un système LTI
# ------
# Content:
# Réponse impulsionnelle
# La réponse impulsionnelle h(t) d'un système S est sa réponse à une entrée sous forme d‘une impulsion de Dirac
# Avantages de la réponse impulsionnelle
# caractérisation complète du système
# permet de calculer la sortie du système LTI pour d’autres signaux
# d’entrée
# ======
# Slide 21 — section : Caractérisation d’un système LTI
# ------
# Content:
# Comment calculer la sortie du système LTI pour un signal d’entrée quelconque à partir de la réponse impulsionnelle ?
# ⇒ notion de convolution
# ======
# Slide 22 — section : Produit de convolution
# ------
# Content:
# On appelle   Produit de convolution  de deux signaux [EQ: 𝑥(𝑡)] et [EQ: 𝑦(𝑡)], et on note [EQ:    𝑥(𝑡)∗𝑦(𝑡)] l’expression:
# Cas de signaux causaux:  [EQ: 𝑥(𝑡)=0,  𝑦(𝑡)=0 pour 𝑡 <0]
# ======
# Slide 23 — section : Produit de convolution : interprétation
# ------
# Content:
# La convolution de [EQ: 𝑥(𝑡)] par [EQ: 𝑦(𝑡)] peut se décomposer en :
# Un retournement:
# Une translation de +t:
# Une multiplication:
# Une intégration:
# Illustration: https://vincmazet.github.io/spetsi/conv1c.html
# ======
# Slide 24 — section : Produit de convolution : interprétation graphique
# ------
# Slide 25 — section : Produit de convolution : Exemple
# ------
# Content:
# Calculer le produit de convolution des signaux suivants:
# ======
# Slide 26 — section : Produit de convolution : Exemple
# ------
# Slide 27 — section : Produit de convolution : Propriétés
# ------
# Content:
# Commutativité :
# Associativité :
# [EQ: 𝑥(𝑡)∗𝑦(𝑡)∗𝑧(𝑡)=𝑥(𝑡)∗(𝑦(𝑡)∗𝑧(𝑡))=[𝑥(𝑡)∗𝑦(𝑡)]∗𝑧(𝑡)]
# Distributivité par rapport à l’addition :
# Elément neutre du produit de convolution: impulsion de Dirac
# [EQ: 𝑥(𝑡)∗𝛿(𝑡)=𝑥(𝑡)]
# Translation temporelle (convolution avec un Dirac retardé )
# ======
# Slide 28 — section : Produit de convolution : Propriétés
# ------
# Content:
# Convolution avec un peigne de Dirac:
# Peigne de Dirarc:           [EQ: Ш_𝑇(𝑡)=𝑘=−∞+∞𝛿(𝑡−𝑘𝑇)]
# [EQ: 𝑓(𝑡)∗] [EQ: Ш_𝑇(𝑡)=] [EQ: 𝑘=−∞+∞𝑓(𝑡)∗𝛿(𝑡−𝑘𝑇)]  (Linéarité de la convolution: on sort la somme)
# [EQ: ⟹]        [EQ: 𝑓(𝑡)∗ Ш_𝑇(𝑡)= 𝑘=−∞+∞𝑓(𝑡−𝑘𝑇)]  (Convolution avec un Dirac retardé)
# [EQ: ⟹ ]On obtient une fonction périodique formée d’une recopie de [EQ: 𝑓 ]autour de
# chaque dent.
# ======
# Slide 29 — section : Réponse d’un système LTI à une entrée quelconque
# ------
# Content:
# Application de la notion de convolution
# .
# ======
# Slide 30 — section : Réponse d’un système LTI à une entrée quelconque
# ------
# Content:
# Application de la notion de convolution
# Elément neutre  de la convolution
# [EQ:       𝑥(𝑡)=𝑥(𝑡)∗𝛿(𝑡)⟹𝑥(𝑡)=−∞+∞𝑥(𝜏)  𝛿(𝑡−𝜏)𝑑𝜏]
# Calculer la sortie de [EQ: 𝑥(𝑡):]  [EQ: 𝑦(𝑡)=𝑆(𝑥(𝑡))]
# [EQ:        ⟹𝑦(𝑡)=𝑆(−∞+∞𝑥(𝜏)  𝛿(𝑡−𝜏)𝑑𝜏)]
# Propriété de linéarité du système [EQ:           𝑦(𝑡)=−∞+∞𝑥(𝜏)  𝑆[𝛿(𝑡−𝜏)]𝑑𝜏]
# Propriété d’invariance temporelle du système:
# [EQ: 𝑆(𝛿(𝑡))=ℎ(𝑡)]      [EQ:         𝑆(𝛿(𝑡−𝜏))=ℎ(𝑡−𝜏)]
# Réponse impulsionnelle décalée
# ======
# Slide 31 — section : Réponse d’un système LTI à une entrée quelconque
# ------
# Content:
# La réponse du système LTI à une entrée quelconque x est la convolution de x avec la réponse impulsionnelle h du système.
# ⇒ La réponse impulsionnelle h caractérise entièrement le système.
# On en déduit [EQ:           𝑦(𝑡)=−∞+∞𝑥(𝜏)  ℎ(𝑡−𝜏)𝑑𝜏      ]
# [EQ:  ⟹]                          [EQ: 𝑦(𝑡)=𝑥(𝑡)∗ℎ(𝑡)]
# ======
# Slide 32 — section : Stabilité et réponse impulsionnelle
# ------
# Content:
# un système est stable si sa sortie est bornée lorsque son entrée est bornée
# Quelle est la condition sur [EQ: ℎ(𝑡) ]pour que [EQ: 𝑦(𝑡) ]soit bornée ?
# ⇒ Un système est stable ssi sa réponse impulsionnelle est absolument
# intégrable:
# ======
# Slide 33 — section : Causalité et réponse impulsionnelle
# ------
# Content:
# Un système SLIT est causal si sa réponse impulsionnelle est nulle pour t < 0 :
# ======

# %% [markdown]
# # Extraction des notions d'un slide
# Puis on extrait les **notions du slide** :
# Les candidats sont extraits via spaCy : le texte du slide est analysé grammaticalement et seuls les groupes nominaux sont retenus comme candidats potentiels de notions. Cela garantit que les candidats sont des unités linguistiques cohérentes (ex: "signaux périodiques", "énergie finie") plutôt que des fragments arbitraires.

# %%
import spacy
import re
from pptx import Presentation

nlp = spacy.load("fr_core_news_sm")


def clean_text(text):
    """
    Nettoyage général du texte
    """

    text = re.sub(r"[\n\r\t]+", " ", text)
    text = re.sub(r"\s{2,}", " ", text)

    return text.strip()


def remove_semantic_duplicates(candidates):
    """
    Supprime les notions courtes incluses dans des notions plus longues

    Exemple :
        "signaux"
        "signaux déterministes"

    => "signaux" supprimé
    """

    # Trier par longueur décroissante
    sorted_candidates = sorted(candidates, key=len, reverse=True)

    final = []

    for cand in sorted_candidates:

        cand_lower = cand.lower()

        # vérifier si déjà inclus dans une notion plus longue
        included = False

        for kept in final:
            kept_lower = kept.lower()

            # mot entier inclus
            if re.search(rf"\b{re.escape(cand_lower)}\b", kept_lower):
                included = True
                break

        if not included:
            final.append(cand)

    # remettre ordre naturel
    final.reverse()

    return final


def extract_candidates(slide_text, section_title=None, min_len=3):

    doc = nlp(slide_text)

    seen = set()
    candidates = []

    for chunk in doc.noun_chunks:

        tokens = []

        for token in chunk:

            # ponctuation
            if token.is_punct:
                continue

            # stop words spaCy
            if token.is_stop:
                continue

            # déterminants / prépositions
            if token.pos_ in {"DET", "ADP"}:
                continue

            # mots trop courts
            if len(token.text.strip()) < min_len:
                continue

            tokens.append(token.text)

        cleaned = " ".join(tokens)

        cleaned = clean_text(cleaned)

        if not cleaned:
            continue

        # longueur minimale
        if len(cleaned) < min_len:
            continue

        # uniquement chiffres
        if cleaned.isdigit():
            continue

        text_norm = cleaned.lower()

        # liens
        if re.search(r"https?://|www\.", text_norm):
            continue

        # contient chiffres
        if re.search(r"[0-9]", cleaned):
            continue

        # caractères spéciaux
        if re.search(r"[^a-zA-ZÀ-ÿ\s\-]", cleaned):
            continue

        # antislash
        if "\\" in cleaned:
            continue

        # caractères de contrôle
        if re.search(r"[\x00-\x1F\x7F]", cleaned):
            continue

        # doublons exacts
        if text_norm in seen:
            continue

        seen.add(text_norm)

        candidates.append(cleaned)

    # suppression des doublons sémantiques
    candidates = remove_semantic_duplicates(candidates)

    # fallback :
    # si aucune notion trouvée → utiliser le titre du slide
    if not candidates and section_title:

        section_title = clean_text(section_title)

        if len(section_title) >= min_len:
            candidates = [section_title]

    return candidates


# -------- lecture PowerPoint --------

for file in PPT_FILES:

    prs = Presentation(file)

    print(f"\n========== {file} ==========\n")

    for i, slide in enumerate(prs.slides):

        slide_number = i + 1

        section = extract_slide_section(slide)

        content = extract_slide_content(
            slide,
            section,
            slide_number
        )

        notions = extract_candidates(
            content,
            section_title=section
        )

        print(f"Slide {slide_number} notions: {notions}")
        print("------")
# Out:
# ========== ../data/1-ppt\Cours_TS_Chap1.pptx ==========
#
# Slide 1 notions: ['signaux', 'Représentation temporelle']
# ------
# Slide 2 notions: ['Nombre', 'discrets', 'Continus', 'critères', 'variables', 'aléatoires', 'Déterministes', 'Signaux réels complexes', 'Classification énergétique']
# ------
# Slide 3 notions: ['Classification en fonction du nombre de variables']
# ------
# Slide 4 notions: ['argument', 'partie réelle', 'Nombre complexe', 'Complexe conjugué', 'partie imaginaire']
# ------
# Slide 5 notions: ['temps', 'classe', 'signal', 'valeur', 'instant', 'évolution', 'signaux périodiques', 'fonction mathématique', 'Signaux déterministes']
# ------
# Slide 6 notions: ['loi', 'temps', 'appel', 'bruit', 'moyenne', 'décrire', 'Exemple', 'variance', 'évolution', 'expérience', 'probabilité', 'Signaux aléatoires', 'propriétés statistiques']
# ------
# Slide 7 notions: ['bruit', 'signal']
# ------
# Slide 8 notions: ['heure', 'cours', 'types', 'bourse', 'instant', 'variable', 'instants Exemple', 'signal analogique', 'signal électrique', 'signaux temporels', 'Traitement numérique', 'Traitement analogique', 'onde électromagnétique']
# ------
# Slide 9 notions: ['types', 'signaux temporels']
# ------
# Slide 10 notions: ['Signaux continus / discrets']
# ------
# Slide 11 notions: ['Signaux continus / discrets']
# ------
# Slide 12 notions: ['Signaux continus / discrets']
# ------
# Slide 13 notions: ['temps', 'basses', 'signal', 'valeurs', 'discret', 'Support', 'pratique', 'Remarque', 'ensemble', 'intervalle', 'nombre fini', 'Cas continu', 'limites hautes', 'signaux physiques']
# ------
# Slide 14 notions: ['signal continu', 'Puissance instantanée']
# ------
# Slide 15 notions: ['somme', 'puissance', 'Energie totale']
# ------
# Slide 16 notions: ['signal', 'valeur moyenne', 'Puissance moyenne']
# ------
# Slide 17 notions: ['signal', 'infinie', 'énergie', 'signaux', 'pratique', 'monde réel', 'puissance moyenne', 'modèles étudiables']
# ------
# Slide 18 notions: ['Exemple', 'période', 'signaux périodiques']
# ------
# Slide 19 notions: ['fois', 'support', 'infinité', 'périodes', 'Propriétés', 'Démonstration', 'petite période', 'signal continu', 'signal périodique']
# ------
# Slide 20 notions: ['Cas', 'fois', 'période', 'infinie', 'infinité', 'puissance moyenne', 'signal périodique', 'signaux périodiques', 'nécessairement énergie']
# ------
# Slide 21 notions: ['rampe', 'infinie', 'énergie', 'support temporal', 'puissance moyenne', 'signaux périodiques', 'signaux transitoires']
# ------
# Slide 22 notions: ['signal', 'Causalité', 'non causal']
# ------
# Slide 23 notions: ['signal']
# ------
# Slide 24 notions: ['somme', 'forme', 'Parité', 'signaux', 'signal pair']
# ------
# Slide 25 notions: ['rapport', 'variable', 'Retournement', 'Transformations']
# ------
# Slide 26 notions: ['gauche', 'droite', 'variable', 'Translation', 'Transformations']
# ------
# Slide 27 notions: ['variable', 'Changement', 'contraction', 'Illustration', 'Transformations']
# ------
# Slide 28 notions: ['variable', 'Changement', 'Transformations']
# ------
# Slide 29 notions: ['Sinusoïde', 'Illustration']
# ------
# Slide 30 notions: ['signal', 'traitement', 'transformées', 'rôle important', 'Sinus Cardinal']
# ------
# Slide 31 notions: ['fonction', 'Signal rectangulaire', 'fenêtrage élémentaire']
# ------
# Slide 32 notions: ['support', 'fenêtrage', 'signal porte', 'Signal rectangulaire']
# ------
# Slide 33 notions: ['Fonction triangulaire']
# ------
# Slide 34 notions: ['unité', 'signal', 'valeur', 'Heaviside', 'convention', 'Fonction échelon']
# ------
# Slide 35 notions: ['valeur', 'défaut', 'origine', 'Fonction']
# ------
# Slide 36 notions: ['aire', 'Dirac', 'flèche', 'symbole', 'Attention', 'Impulsion', 'schématise', 'non hauteur']
# ------
# Slide 37 notions: ['Dirac', 'valeur', 'fonction', 'distribution']
# ------
# Slide 38 notions: ['Dirac', 'Remarque', 'tendrait', 'Impulsion', 'Illustration', 'fonction échelon']
# ------
# Slide 39 notions: ['Dirac']
# ------
# Slide 40 notions: ['somme', 'Dirac', 'peigne', 'période', 'infinie', 'impulsions']
# ------
# Slide 41 notions: ['fonction', 'processus', 'échantillonnage']
# ------
# Slide 42 notions: ['finie', 'infini', 'signal', 'Energie', 'Support', 'Discret', 'Continu', 'puissance', 'Périodique', 'cas courants', 'énergie totale', 'totale infinie', 'Signaux périodiques', 'Période fondamentale']
# ------
# Slide 43 notions: ['finie', 'temps', 'causal', 'mesure', 'continu', 'capteur', 'ensemble', 'fonction', 'appareil', 'contraintes', 'durée limitée', 'support borné', 'énergie bornée', 'amplitude bornée', 'signal expérimental']
# ------
# Slide 44 notions: ['aisée', 'étude', 'signal', 'définie', 'infinie', 'modèles', 'temps infini', 'discontinuités', 'plan théorique', 'caractéristiques', 'énergie théorique', 'amplitude non bornée', 'signaux expérimentaux', 'fonction réelle complexe']
# ------
#
# ========== ../data/1-ppt\Cours_TS_Chap2.pptx ==========
#
# Slide 1 notions: ['Définition', 'caractérisation', 'Systèmes linéaires']
# ------
# Slide 2 notions: ['LTI', 'Notion', 'entrée', 'système', 'systèmes', 'Définition', 'convolution', 'Introduction', 'Classification', 'Réponse impulsionnelle', 'Caractérisation temporelle']
# ------
# Slide 3 notions: ['systèmes', 'Exemples']
# ------
# Slide 4 notions: ['lien', 'cause', 'sortie', 'entrées', 'signaux', 'système', 'éléments fonctionnels']
# ------
# Slide 5 notions: ['sortie', 'entrée', 'signal', 'système']
# ------
# Slide 6 notions: ['nombre', 'sortie', 'entrée', 'sorties', 'entrées', 'système', 'Systèmes mono-variable multi-variable']
# ------
# Slide 7 notions: ['système', 'réponse', 'Causalité', 'excitation']
# ------
# Slide 8 notions: ['temps', 'sortie', 'entrée', 'système', 'réponse', 'décalage', 'translation', 'Invariance temporelle']
# ------
# Slide 9 notions: ['sortie', 'système', 'perturbé', 'Stabilité', 'disparition', 'perturbation', 'état initial', 'entrée bornée']
# ------
# Slide 10 notions: ['LTI', 'temps', 'suite', 'heure', 'tarif', 'causal', 'Sortie', 'Entrée', 'système', 'Exemple', 'Vitesse', 'linéaire', 'aiguille', 'parcmètre', 'Propriétés', 'Tachymètre', 'Position angulaire', 'systèmes mono-variables']
# ------
# Slide 11 notions: ['Linéarité']
# ------
# Slide 12 notions: ['Linéarité']
# ------
# Slide 13 notions: ['Linéarité']
# ------
# Slide 14 notions: ['Invariance temporelle']
# ------
# Slide 15 notions: ['système', 'Exemple']
# ------
# Slide 16 notions: ['système', 'Exemple']
# ------
# Slide 17 notions: ['sortie', 'système', 'connaissance', 'Relation entrée', 'coefficients constants', 'équation différentielle', 'Caractérisation complète']
# ------
# Slide 18 notions: ['sortie', 'Relation entrée', 'équation différentielle', 'coefficients constants Exemple']
# ------
# Slide 19 notions: ['Dirac', 'forme', 'entrée', 'système', 'Réponse impulsionnelle']
# ------
# Slide 20 notions: ['LTI', 'Dirac', 'forme', 'sortie', 'entrée', 'signaux', 'système', 'Avantages', 'Réponse impulsionnelle']
# ------
# Slide 21 notions: ['LTI', 'entrée', 'signal', 'sortie', 'système', 'convolution']
# ------
# Slide 22 notions: ['Cas', 'Produit', 'expression', 'convolution', 'signaux causaux']
# ------
# Slide 23 notions: ['intégration', 'translation', 'convolution', 'Illustration', 'retournement', 'multiplication']
# ------
# Slide 24 notions: ['Produit de convolution : interprétation graphique']
# ------
# Slide 25 notions: ['signaux', 'produit', 'convolution']
# ------
# Slide 26 notions: ['Produit de convolution : Exemple']
# ------
# Slide 27 notions: ['Dirac', 'produit', 'rapport', 'addition', 'impulsion', 'convolution', 'Associativité', 'Commutativité', 'Distributivité', 'Translation temporelle']
# ------
# Slide 28 notions: ['somme', 'Dirac', 'Dirarc', 'peigne', 'recopie', 'Convolution', 'fonction périodique']
# ------
# Slide 29 notions: ['notion', 'convolution', 'Application']
# ------
# Slide 30 notions: ['sortie', 'notion', 'système', 'linéarité', 'Propriété', 'convolution', 'Application', 'Réponse impulsionnelle']
# ------
# Slide 31 notions: ['LTI', 'entrée', 'système', 'réponse impulsionnelle']
# ------
# Slide 32 notions: ['entrée', 'sortie', 'système', 'condition', 'réponse impulsionnelle']
# ------
# Slide 33 notions: ['système SLIT', 'réponse impulsionnelle']
# ------

# %% [markdown]
# On remarque que les notions associées à chaque slide ne sont pas convenables. En effet, même si le contenu est traité lignuistiquement et structuré par groupes nominaux, on n'a pas une façon réelle pour différencier entre une notion(ex: "signaux périodiques", "énergie finie") et un mot quelconque(ex : "Nombre", etc).
# **On doit alors ajouter à cette méthode de structuration grammaticale une méthode de compréhension sémantique.**

# %% [markdown]
# La méthode de compréhension sémantique qu'on utilisera est l'**embeddings**, consistant à transformer les mots en vecteurs numériques denses permettant aux machines de comprendre le sens des mots et leur proximité **sémantique**.
# On commence par importer le modèle responsable de la représentation vectorielle du texte.

# %%
import os
os.environ["TQDM_DISABLE"] = "1"

# Force tqdm to use plain text mode - must happen before sentence_transformers import
from tqdm.auto import tqdm as tqdm_auto
from tqdm import tqdm as tqdm_std
import tqdm.auto
tqdm.auto.tqdm = tqdm_std  # replace notebook/widget tqdm with plain text tqdm

from sentence_transformers import SentenceTransformer
import numpy as np

model = SentenceTransformer("intfloat/multilingual-e5-base")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|█████████████████████████████████████████████████████████████| 199/199 [00:00<00:00, 1533.95it/s]
# XLMRobertaModel LOAD REPORT from: intfloat/multilingual-e5-base
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# Voici la fonction qui extrait les notions de chaque slide en combinant une analyse linguistique et une méthode sémantique par embeddings.
#
# Son principe consiste à d'abord générer des candidats linguistiquement valides à partir du contenu du slide, puis à sélectionner parmi eux les plus pertinents par rapport au contexte du slide.
#
# Pour la similarité sémantique, la référence utilisée pour la comparaison est construite à partir de trois niveaux de contexte : le nom du chapitre, le titre de la section, et une partie du contenu du slide.
#
# Les étapes sont les suivantes :
# - analyser le texte du slide et extraire les groupes nominaux comme candidats
# - construire la référence contextuelle : `chapitre + section + contenu (50 premiers mots)`
# - calculer l'embedding de la référence et l'embedding de chaque candidat
# - comparer les embeddings à l'aide de la similarité cosinus (valeur entre 0 et 1, où 1 indique une forte similarité)
# - trier les candidats par ordre décroissant de similarité
# - sélectionner les `top_k` candidats dépassant le seuil `threshold` comme notions

# %%
def extract_notions(
    chapter_name,
    section_title,
    slide_text,
    top_k=3,
    threshold=0.35
):
    """
    Extraction des notions pertinentes d'un slide
    avec :
      - nettoyage
      - suppression stop words
      - suppression mots courts
      - suppression doublons sémantiques
      - fallback sur le titre du slide
    """

    # -------- extraction des candidats --------
    candidates = extract_candidates(
        slide_text,
        section_title=section_title,
        min_len=3
    )

    # fallback sécurité
    if not candidates:

        cleaned_title = clean_text(section_title)

        if cleaned_title:
            return [cleaned_title]

        return []

    # -------- contexte multi-niveaux --------

    short_content = " ".join(slide_text.split()[:50])

    query = (
        f"query: "
        f"{chapter_name}. "
        f"{section_title}. "
        f"{short_content}"
    )

    passages = [
        f"passage: {c}"
        for c in candidates
    ]

    # -------- embeddings --------

    query_emb = model.encode(
        [query],
        normalize_embeddings=True
    )

    passage_embs = model.encode(
        passages,
        normalize_embeddings=True
    )

    # -------- similarité cosinus --------

    scores = np.dot(
        passage_embs,
        query_emb.T
    ).flatten()

    # -------- ranking --------

    ranked = sorted(
        zip(candidates, scores),
        key=lambda x: x[1],
        reverse=True
    )

    # -------- filtrage --------

    notions = [
        text
        for text, score in ranked
        if score >= threshold
    ]

    # -------- suppression doublons sémantiques --------

    notions = remove_semantic_duplicates(notions)

    # -------- top_k --------

    notions = notions[:top_k]

    # -------- fallback final --------

    if not notions:

        cleaned_title = clean_text(section_title)

        if cleaned_title:
            notions = [cleaned_title]

    return notions


# -------- lecture des fichiers PowerPoint --------

for file in PPT_FILES:

    prs = Presentation(file)

    # -------- nom du chapitre --------

    first_slide_text = "\n".join(
        shape.text
        for shape in prs.slides[0].shapes
        if shape.has_text_frame
    )

    chap_name = extract_chapter_name(
        first_slide_text,
        file
    )

    print(f"\n========== {file} ==========\n")

    # -------- parcours slides --------

    for i, slide in enumerate(prs.slides):

        slide_number = i + 1

        section = extract_slide_section(slide)

        content = extract_slide_content(
            slide,
            section,
            slide_number
        )

        notions = extract_notions(
            chap_name,
            section,
            content,
            top_k=3,
            threshold=0.35
        )

        print(f"Slide {slide_number} notions: {notions}")
        print("------")
# Out:
# ========== ../data/1-ppt\Cours_TS_Chap1.pptx ==========
#
# Slide 1 notions: ['signaux', 'Représentation temporelle']
# ------
# Slide 2 notions: ['Nombre', 'Continus', 'discrets']
# ------
# Slide 3 notions: ['Classification en fonction du nombre de variables']
# ------
# Slide 4 notions: ['argument', 'partie réelle', 'Nombre complexe']
# ------
# Slide 5 notions: ['temps', 'classe', 'signal']
# ------
# Slide 6 notions: ['loi', 'appel', 'temps']
# ------
# Slide 7 notions: ['bruit', 'signal']
# ------
# Slide 8 notions: ['types', 'cours', 'heure']
# ------
# Slide 9 notions: ['types', 'signaux temporels']
# ------
# Slide 10 notions: ['Signaux continus / discrets']
# ------
# Slide 11 notions: ['Signaux continus / discrets']
# ------
# Slide 12 notions: ['Signaux continus / discrets']
# ------
# Slide 13 notions: ['temps', 'basses', 'signal']
# ------
# Slide 14 notions: ['signal continu', 'Puissance instantanée']
# ------
# Slide 15 notions: ['somme', 'puissance', 'Energie totale']
# ------
# Slide 16 notions: ['signal', 'valeur moyenne', 'Puissance moyenne']
# ------
# Slide 17 notions: ['signal', 'énergie', 'infinie']
# ------
# Slide 18 notions: ['Exemple', 'période', 'signaux périodiques']
# ------
# Slide 19 notions: ['fois', 'support', 'infinité']
# ------
# Slide 20 notions: ['Cas', 'fois', 'infinie']
# ------
# Slide 21 notions: ['rampe', 'infinie', 'énergie']
# ------
# Slide 22 notions: ['signal', 'Causalité', 'non causal']
# ------
# Slide 23 notions: ['signal']
# ------
# Slide 24 notions: ['forme', 'somme', 'Parité']
# ------
# Slide 25 notions: ['rapport', 'variable', 'Retournement']
# ------
# Slide 26 notions: ['gauche', 'droite', 'variable']
# ------
# Slide 27 notions: ['variable', 'Changement', 'contraction']
# ------
# Slide 28 notions: ['variable', 'Changement', 'Transformations']
# ------
# Slide 29 notions: ['Sinusoïde', 'Illustration']
# ------
# Slide 30 notions: ['signal', 'traitement', 'transformées']
# ------
# Slide 31 notions: ['fonction', 'Signal rectangulaire', 'fenêtrage élémentaire']
# ------
# Slide 32 notions: ['support', 'fenêtrage', 'signal porte']
# ------
# Slide 33 notions: ['Fonction triangulaire']
# ------
# Slide 34 notions: ['unité', 'signal', 'valeur']
# ------
# Slide 35 notions: ['défaut', 'valeur', 'origine']
# ------
# Slide 36 notions: ['aire', 'Dirac', 'flèche']
# ------
# Slide 37 notions: ['Dirac', 'valeur', 'fonction']
# ------
# Slide 38 notions: ['Dirac', 'tendrait', 'Remarque']
# ------
# Slide 39 notions: ['Dirac']
# ------
# Slide 40 notions: ['somme', 'Dirac', 'peigne']
# ------
# Slide 41 notions: ['fonction', 'processus', 'échantillonnage']
# ------
# Slide 42 notions: ['finie', 'infini', 'signal']
# ------
# Slide 43 notions: ['finie', 'temps', 'causal']
# ------
# Slide 44 notions: ['aisée', 'étude', 'signal']
# ------
#
# ========== ../data/1-ppt\Cours_TS_Chap2.pptx ==========
#
# Slide 1 notions: ['Définition', 'caractérisation', 'Systèmes linéaires']
# ------
# Slide 2 notions: ['LTI', 'Notion', 'entrée']
# ------
# Slide 3 notions: ['systèmes', 'Exemples']
# ------
# Slide 4 notions: ['lien', 'cause', 'sortie']
# ------
# Slide 5 notions: ['sortie', 'signal', 'entrée']
# ------
# Slide 6 notions: ['nombre', 'sortie', 'entrée']
# ------
# Slide 7 notions: ['réponse', 'système', 'Causalité']
# ------
# Slide 8 notions: ['temps', 'sortie', 'entrée']
# ------
# Slide 9 notions: ['sortie', 'système', 'perturbé']
# ------
# Slide 10 notions: ['LTI', 'suite', 'tarif']
# ------
# Slide 11 notions: ['Linéarité']
# ------
# Slide 12 notions: ['Linéarité']
# ------
# Slide 13 notions: ['Linéarité']
# ------
# Slide 14 notions: ['Invariance temporelle']
# ------
# Slide 15 notions: ['système', 'Exemple']
# ------
# Slide 16 notions: ['système', 'Exemple']
# ------
# Slide 17 notions: ['sortie', 'système', 'connaissance']
# ------
# Slide 18 notions: ['sortie', 'Relation entrée', 'équation différentielle']
# ------
# Slide 19 notions: ['forme', 'Dirac', 'entrée']
# ------
# Slide 20 notions: ['LTI', 'forme', 'Dirac']
# ------
# Slide 21 notions: ['LTI', 'signal', 'sortie']
# ------
# Slide 22 notions: ['Cas', 'Produit', 'expression']
# ------
# Slide 23 notions: ['translation', 'intégration', 'convolution']
# ------
# Slide 24 notions: ['Produit de convolution : interprétation graphique']
# ------
# Slide 25 notions: ['produit', 'signaux', 'convolution']
# ------
# Slide 26 notions: ['Produit de convolution : Exemple']
# ------
# Slide 27 notions: ['Dirac', 'rapport', 'produit']
# ------
# Slide 28 notions: ['somme', 'Dirac', 'peigne']
# ------
# Slide 29 notions: ['notion', 'Application', 'convolution']
# ------
# Slide 30 notions: ['notion', 'sortie', 'système']
# ------
# Slide 31 notions: ['LTI', 'entrée', 'système']
# ------
# Slide 32 notions: ['sortie', 'entrée', 'système']
# ------
# Slide 33 notions: ['système SLIT', 'réponse impulsionnelle']
# ------

# %% [markdown]
# Le résultat donné par ces deux méthodes combinés est plus efficace que la 1ère méthode, toujours avec une marge d'amélioration possible.

# %% [markdown]
# # Extraction des catégories dans un slide
# On passe à **catégoriser le contenu du slide**. Pour l'instant, les catégories possibles du contenu d'un slide qu'on va fixer sont : définition, exemple, remarque, formule mathématique. Un slide peut alors avoir plus qu'une seule catégorie.
# On commence par détecter les formules :

# %%
from pptx import Presentation
from lxml import etree

MC_NS   = "http://schemas.openxmlformats.org/markup-compatibility/2006"
DML_NS  = "http://schemas.openxmlformats.org/drawingml/2006/main"
MATH_NS = "http://schemas.openxmlformats.org/officeDocument/2006/math"


# ── Détection et extraction des formules ─────────────────────────────────────

def detect_formulas(slide, slide_number):
    """
    Détecte et extrait toutes les formules mathématiques d'un slide.

    Types gérés :
      - OMML  (<m:oMath>)  : format moderne, texte extrait via extract_math()
      - OLE   (shape_type 7) : ancien Equation Editor 3.0, non extractable
    
    Retourne une liste de dicts :
      {
        formula_id   : int,
        slide        : int,
        shape_name   : str,
        type         : "OMML" | "OLE",
        extractable  : bool,
        text         : str | None,   # résultat lisible ou None
        raw_itertext : str | None,   # texte brut XML (debug)
      }
    """
    formulas   = []
    formula_id = 1

    # ── 1. Shapes normales ───────────────────────────────────────────────────
    for shape in slide.shapes:
        xml_str = shape._element.xml

        # 1a. OMML dans une shape normale
        if "<m:oMath" in xml_str:
            tree          = etree.fromstring(xml_str.encode())
            math_elements = tree.findall(f".//{{{MATH_NS}}}oMath")
            for m in math_elements:
                readable   = extract_math(m).strip()
                raw_itext  = "".join(m.itertext()).strip()
                formulas.append({
                    "formula_id"   : formula_id,
                    "slide"        : slide_number,
                    "shape_name"   : shape.name,
                    "type"         : "OMML",
                    "extractable"  : True,
                    "text"         : readable  or raw_itext or None,
                    "raw_itertext" : raw_itext or None,
                })
                formula_id += 1

        # 1b. OLE — ancien Equation Editor
        elif shape.shape_type == 7:
            formulas.append({
                "formula_id"   : formula_id,
                "slide"        : slide_number,
                "shape_name"   : shape.name,
                "type"         : "OLE",
                "extractable"  : False,
                "text"         : None,
                "raw_itertext" : None,
            })
            formula_id += 1

    # ── 2. AlternateContent (équations embarquées dans du texte) ─────────────
    for child in slide.shapes._spTree:
        if child.tag != f'{{{MC_NS}}}AlternateContent':
            continue

        choice = child.find(f'{{{MC_NS}}}Choice')
        source = choice if choice is not None else child.find(f'{{{MC_NS}}}Fallback')
        if source is None:
            continue

        math_elements = source.findall(f".//{{{MATH_NS}}}oMath")
        for m in math_elements:
            readable  = extract_math(m).strip()
            raw_itext = "".join(m.itertext()).strip()
            formulas.append({
                "formula_id"   : formula_id,
                "slide"        : slide_number,
                "shape_name"   : "AlternateContent",
                "type"         : "OMML",
                "extractable"  : True,
                "text"         : readable  or raw_itext or None,
                "raw_itertext" : raw_itext or None,
            })
            formula_id += 1

    return formulas


# ── Extraction globale ────────────────────────────────────────────────────────

def extract_all_formulas(prs):
    all_formulas = []

    for i, slide in enumerate(prs.slides):
        slide_formulas = detect_formulas(slide, slide_number=i + 1)
        all_formulas.extend(slide_formulas)

    # Garder uniquement :
    #  - les OLE (non extractables, on ne peut pas vérifier)
    #  - les OMML dont le texte contient "="
    all_formulas = [
        f for f in all_formulas
        if not f["extractable"] or (f["text"] and "=" in f["text"])
    ]

    # -------- renumérotation globale à partir de 1 --------
    for idx, f in enumerate(all_formulas, start=1):
        f["formula_id"] = idx

    stats = {
        "total"      : len(all_formulas),
        "omml"       : sum(1 for f in all_formulas if f["type"] == "OMML"),
        "ole"        : sum(1 for f in all_formulas if f["type"] == "OLE"),
        "extractable": sum(1 for f in all_formulas if f["extractable"]),
        "per_slide"  : {},
    }
    for f in all_formulas:
        stats["per_slide"].setdefault(f["slide"], 0)
        stats["per_slide"][f["slide"]] += 1

    return all_formulas, stats


# ── Affichage ─────────────────────────────────────────────────────────────────

def print_formulas(all_formulas, stats):
    print(f"\n{'═'*55}")
    print(f"  {stats['total']} formule(s) — "
          f"{stats['omml']} OMML / {stats['ole']} OLE / "
          f"{stats['extractable']} extractable(s)")
    print(f"{'═'*55}")

    current_slide = None
    for f in all_formulas:
        if f["slide"] != current_slide:
            current_slide = f["slide"]
            print(f"\n── Slide {current_slide} "
                  f"({stats['per_slide'][current_slide]} formule(s)) ──")

        status = "✓" if f["extractable"] else "✗"
        print(f"  [{status}] #{f['formula_id']}  {f['type']}"
              f"  shape=«{f['shape_name']}»")
        if f["text"]:
            print(f"       → {f['text']}")
        else:
            print(f"       → (non extractable)")

    print(f"\n{'═'*55}\n")


# ── Point d'entrée ────────────────────────────────────────────────────────────

for file in PPT_FILES:

    prs = Presentation(file)

    # Récupération du nom du chapitre depuis la première slide
    first_slide_text = "\n".join(
        shape.text
        for shape in prs.slides[0].shapes
        if shape.has_text_frame
    )

    chap_name = extract_chapter_name(first_slide_text, file)

    print(f"\n========== {file} ==========\n")
    print(f"Chapitre : {chap_name}\n")

    # Extraction des formules DU fichier courant
    all_formulas, stats = extract_all_formulas(prs)

    # Affichage
    print_formulas(all_formulas, stats)
# Out:
# ========== ../data/1-ppt\Cours_TS_Chap1.pptx ==========
#
# Chapitre : Représentation temporelle des signaux
#
#
# ═══════════════════════════════════════════════════════
#   38 formule(s) — 38 OMML / 0 OLE / 38 extractable(s)
# ═══════════════════════════════════════════════════════
#
# ── Slide 4 (8 formule(s)) ──
#   [✓] #1  OMML  shape=«AlternateContent»
#        → 𝑗: 𝑗^2=−1
#   [✓] #2  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)=𝑎(𝑡)+𝑗 𝑏(𝑡)
#   [✓] #3  OMML  shape=«AlternateContent»
#        → 𝑅𝑒(𝑥(𝑡))=𝑎(𝑡)
#   [✓] #4  OMML  shape=«AlternateContent»
#        → 𝐼𝑚(𝑥(𝑡))=𝑏(𝑡)
#   [✓] #5  OMML  shape=«AlternateContent»
#        → (𝑥(𝑡))=√(𝑎2𝑡+𝑏2𝑡)
#   [✓] #6  OMML  shape=«AlternateContent»
#        → 𝐴𝑟𝑔(𝑥(𝑡))=𝑎𝑟𝑐𝑡𝑎𝑛((𝑏(𝑡)/𝑎(𝑡)))
#   [✓] #7  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)=(𝑥(𝑡))𝑒^𝑗𝐴𝑟𝑔𝑥𝑡
#   [✓] #8  OMML  shape=«AlternateContent»
#        → 𝑥^∗(𝑡)=𝑎(𝑡)−𝑗 𝑏(𝑡)=(𝑥(𝑡))𝑒^−𝑗𝐴𝑟𝑔𝑥𝑡
#
# ── Slide 15 (1 formule(s)) ──
#   [✓] #9  OMML  shape=«AlternateContent»
#        → 𝐸_𝑥=−∞+∞𝑥(𝑡)^2𝑑𝑡
#
# ── Slide 16 (1 formule(s)) ──
#   [✓] #10  OMML  shape=«AlternateContent»
#        → 𝑃_𝑥=lim𝑇→+∞   (1/𝑇)−(𝑇/2)+(𝑇/2)𝑥(𝑡)^2𝑑𝑡
#
# ── Slide 18 (3 formule(s)) ──
#   [✓] #11  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)=𝑥(𝑡+𝑘 𝑇_0), 𝑘∈ ℤ
#   [✓] #12  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)=sin(2 𝜋 𝑓_0𝑡)
#   [✓] #13  OMML  shape=«AlternateContent»
#        → 𝑇_0=(1/𝑓0)
#
# ── Slide 20 (1 formule(s)) ──
#   [✓] #14  OMML  shape=«AlternateContent»
#        → 𝑃_𝑥=   (1/𝑇0)0𝑇_0𝑥(𝑡)^2𝑑𝑡
#
# ── Slide 21 (1 formule(s)) ──
#   [✓] #15  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)=𝑡
#
# ── Slide 22 (1 formule(s)) ──
#   [✓] #16  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)=0, ∀ 𝑡<0
#
# ── Slide 23 (2 formule(s)) ──
#   [✓] #17  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)=𝑥(−𝑡)
#   [✓] #18  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)=−𝑥(−𝑡)
#
# ── Slide 30 (1 formule(s)) ──
#   [✓] #19  OMML  shape=«AlternateContent»
#        → 𝑠𝑖𝑛𝑐(𝑡)=( 1                  si 𝑡=0(sin𝜋𝑡/𝜋𝑡)        sinon)
#
# ── Slide 31 (1 formule(s)) ──
#   [✓] #20  OMML  shape=«AlternateContent»
#        → 𝑟𝑒𝑐𝑡_𝑇(𝑡)=(1    si (−𝑇/2)≤𝑡 ≤(𝑇/2)0                        sinon)
#
# ── Slide 33 (1 formule(s)) ──
#   [✓] #21  OMML  shape=«AlternateContent»
#        → t𝑟𝑖(𝑡)=(1− (𝑡)  pour   (𝑡)≤10             pour   (𝑡)>1)
#
# ── Slide 34 (2 formule(s)) ──
#   [✓] #22  OMML  shape=«AlternateContent»
#        → Γ(𝑡)=(0    pour   𝑡<01    pour   𝑡≥0)
#   [✓] #23  OMML  shape=«AlternateContent»
#        → Γ(𝑡)=1
#
# ── Slide 35 (3 formule(s)) ──
#   [✓] #24  OMML  shape=«AlternateContent»
#        → 𝑠𝑔𝑛(𝑡)=(−1    pour   𝑡<01    pour   𝑡≥0)
#   [✓] #25  OMML  shape=«AlternateContent»
#        → 𝑠𝑔𝑛(𝑡)=1
#   [✓] #26  OMML  shape=«AlternateContent»
#        → t=0
#
# ── Slide 36 (1 formule(s)) ──
#   [✓] #27  OMML  shape=«AlternateContent»
#        → 𝛿(𝑡)=(0 pour   𝑡≠0 +∞  pour   𝑡=0)
#
# ── Slide 37 (4 formule(s)) ──
#   [✓] #28  OMML  shape=«AlternateContent»
#        → ∞+∞𝛿(𝑡)𝑑𝑡=1
#   [✓] #29  OMML  shape=«AlternateContent»
#        → 𝛿(𝑡)=0,     ∀ 𝑡 ≠0
#   [✓] #30  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡).𝛿(𝑡)=𝑥(0).𝛿(𝑡)
#   [✓] #31  OMML  shape=«AlternateContent»
#        → ∞+∞𝑥(𝑡)𝛿(𝑡)𝑑𝑡=𝑥(0))
#
# ── Slide 38 (2 formule(s)) ──
#   [✓] #32  OMML  shape=«AlternateContent»
#        → 𝛿(𝑡)=lim𝑇→0(1/𝑇)𝑟𝑒𝑐𝑡_𝑇(𝑡)
#   [✓] #33  OMML  shape=«AlternateContent»
#        → 𝛿(𝑡)=(𝑑Γ(𝑡)/𝑑𝑡)
#
# ── Slide 39 (3 formule(s)) ──
#   [✓] #34  OMML  shape=«AlternateContent»
#        → −∞+∞𝛿(𝑡−𝑡_0)dt=1
#   [✓] #35  OMML  shape=«AlternateContent»
#        → 𝛿(𝑡−𝑡_0)=0     ∀ 𝑡 ≠𝑡_0
#   [✓] #36  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)𝛿(𝑡−𝑡_0)=𝑥(𝑡_0)𝛿(𝑡−𝑡_0)
#
# ── Slide 40 (1 formule(s)) ──
#   [✓] #37  OMML  shape=«AlternateContent»
#        → Ш_𝑇(𝑡)=𝑘=−∞+∞𝛿(𝑡−𝑘𝑇)
#
# ── Slide 41 (1 formule(s)) ──
#   [✓] #38  OMML  shape=«AlternateContent»
#        → 𝑓𝑡. Ш_T(𝑡)=𝑘=−∞+∞𝑓(𝑘𝑇)  𝛿(𝑡−𝑘𝑇)
#
# ═══════════════════════════════════════════════════════
#
#
# ========== ../data/1-ppt\Cours_TS_Chap2.pptx ==========
#
# Chapitre : Systèmes linéaires continus
#
#
# ═══════════════════════════════════════════════════════
#   28 formule(s) — 28 OMML / 0 OLE / 28 extractable(s)
# ═══════════════════════════════════════════════════════
#
# ── Slide 6 (2 formule(s)) ──
#   [✓] #1  OMML  shape=«AlternateContent»
#        → i 𝑥(𝑡)=𝑎_1𝑥_1(𝑡)+𝑎_2𝑥_2(𝑡)
#   [✓] #2  OMML  shape=«AlternateContent»
#        → 𝑦(𝑡)=𝑎_1𝑆(𝑥_1(𝑡))+𝑎_2𝑆(𝑥_2(𝑡))
#
# ── Slide 7 (2 formule(s)) ──
#   [✓] #3  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)=0
#   [✓] #4  OMML  shape=«AlternateContent»
#        → y(𝑡)=𝑆(𝑥(𝑡))=0
#
# ── Slide 8 (2 formule(s)) ──
#   [✓] #5  OMML  shape=«AlternateContent»
#        → y(𝑡)=𝑆(𝑥(𝑡))
#   [✓] #6  OMML  shape=«AlternateContent»
#        → y(𝑡−𝑡_0)=𝑆(𝑥(𝑡−𝑡_0))
#
# ── Slide 9 (1 formule(s)) ──
#   [✓] #7  OMML  shape=«AlternateContent»
#        → ∃(  𝑀𝑥/  𝑥(𝑡)<𝑀𝑥  ⇒∃   𝑀𝑦  y𝑡=𝑆𝑥(𝑡)<𝑀𝑦  )
#
# ── Slide 22 (3 formule(s)) ──
#   [✓] #8  OMML  shape=«AlternateContent»
#        → 𝑧(𝑡)=𝑥(𝑡)∗𝑦(𝑡)=−∞+∞𝑥(𝜏)  𝑦(𝑡−𝜏)𝑑𝜏
#   [✓] #9  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)=0,  𝑦(𝑡)=0 pour 𝑡 <0
#   [✓] #10  OMML  shape=«AlternateContent»
#        → 𝑧(𝑡)=𝑥(𝑡)∗𝑦(𝑡)=0+∞𝑥(𝜏)  𝑦(𝑡−𝜏)𝑑𝜏
#
# ── Slide 27 (5 formule(s)) ──
#   [✓] #11  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)∗𝑦(𝑡)=𝑦(𝑡)∗𝑥(𝑡)
#   [✓] #12  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)∗𝑦(𝑡)∗𝑧(𝑡)=𝑥(𝑡)∗(𝑦(𝑡)∗𝑧(𝑡))=[𝑥(𝑡)∗𝑦(𝑡)]∗𝑧(𝑡)
#   [✓] #13  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)∗(𝑦(𝑡)+𝑧(𝑡))=𝑥(𝑡)∗𝑦(𝑡)+𝑥(𝑡)∗𝑧(𝑡)
#   [✓] #14  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)∗𝛿(𝑡)=𝑥(𝑡)
#   [✓] #15  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)∗𝛿(𝑡−𝑡_0)=𝑥(𝑡−𝑡_0)
#
# ── Slide 28 (4 formule(s)) ──
#   [✓] #16  OMML  shape=«AlternateContent»
#        → Ш_𝑇(𝑡)=𝑘=−∞+∞𝛿(𝑡−𝑘𝑇)
#   [✓] #17  OMML  shape=«AlternateContent»
#        → Ш_𝑇(𝑡)=
#   [✓] #18  OMML  shape=«AlternateContent»
#        → 𝑘=−∞+∞𝑓(𝑡)∗𝛿(𝑡−𝑘𝑇)
#   [✓] #19  OMML  shape=«AlternateContent»
#        → 𝑓(𝑡)∗ Ш_𝑇(𝑡)= 𝑘=−∞+∞𝑓(𝑡−𝑘𝑇)
#
# ── Slide 30 (6 formule(s)) ──
#   [✓] #20  OMML  shape=«AlternateContent»
#        → 𝑥(𝑡)=𝑥(𝑡)∗𝛿(𝑡)⟹𝑥(𝑡)=−∞+∞𝑥(𝜏)  𝛿(𝑡−𝜏)𝑑𝜏
#   [✓] #21  OMML  shape=«AlternateContent»
#        → 𝑦(𝑡)=𝑆(𝑥(𝑡))
#   [✓] #22  OMML  shape=«AlternateContent»
#        → ⟹𝑦(𝑡)=𝑆(−∞+∞𝑥(𝜏)  𝛿(𝑡−𝜏)𝑑𝜏)
#   [✓] #23  OMML  shape=«AlternateContent»
#        → 𝑦(𝑡)=−∞+∞𝑥(𝜏)  𝑆[𝛿(𝑡−𝜏)]𝑑𝜏
#   [✓] #24  OMML  shape=«AlternateContent»
#        → 𝑆(𝛿(𝑡))=ℎ(𝑡)
#   [✓] #25  OMML  shape=«AlternateContent»
#        → 𝑆(𝛿(𝑡−𝜏))=ℎ(𝑡−𝜏)
#
# ── Slide 31 (2 formule(s)) ──
#   [✓] #26  OMML  shape=«AlternateContent»
#        → 𝑦(𝑡)=−∞+∞𝑥(𝜏)  ℎ(𝑡−𝜏)𝑑𝜏
#   [✓] #27  OMML  shape=«AlternateContent»
#        → 𝑦(𝑡)=𝑥(𝑡)∗ℎ(𝑡)
#
# ── Slide 33 (1 formule(s)) ──
#   [✓] #28  OMML  shape=«AlternateContent»
#        → ℎ(𝑡)=𝑂 ,      ∀ 𝑡<𝑂
#
# ═══════════════════════════════════════════════════════

# %%
import re
import os

IMAGE_OUTPUT_DIR = "../data/extracted_images"

CATEGORY_KEYWORDS = {
    "definition": [
        r"\bon appelle\b", r"\bon definit\b", r"\bs\'appelle\b",
        r"\best defini\b", r"\best appele\b", r"\bdefinition\b",
        r"\bon note\b", r"\bse definit\b", r"\bcorrespond a\b",
        r"\bse note\b", r"\bdesigne\b"
    ],
    "exemple": [
        r"\bexemple\b", r"\bpar exemple\b", r"\billustration\b",
        r"\bapplication\b", r"\bcas particulier\b", r"\bnotamment\b",
        r"\be\.g\b"
    ],
    "remarque": [
        r"\bremarque\b", r"\bnote\b", r"\battention\b",
        r"\bon remarque\b", r"\bon note que\b", r"\bobservation\b",
        r"\ben pratique\b", r"\ben effet\b"
    ]
}

def get_slide_image_paths(slide_number, chap_id=1, image_dir=IMAGE_OUTPUT_DIR):
    """
    Retourne la liste des chemins des images extraites pour un slide donné.
    Convention de nommage : data/extracted_images/chapitre{C}/slide{N}_img{M}.ext
    """
    # Cherche dans le sous-dossier chapitre{chap_id}
    chap_dir = os.path.join(image_dir, f"chapitre{chap_id}")
    if not os.path.isdir(chap_dir):
        return []
    prefix = f"slide{slide_number}_img"
    return sorted(
        os.path.join(chap_dir, fname)
        for fname in os.listdir(chap_dir)
        if fname.startswith(prefix)
    )

def extract_categories(slide, slide_content, slide_number, chap_id=1):
    # Détection des formules
    formulas = detect_formulas(slide, slide_number)
    formulas = [
        f for f in formulas
        if not f["extractable"] or (f["text"] and "=" in f["text"])
    ]

    # Chemins des images pour ce slide (chap_id transmis correctement)
    image_paths = get_slide_image_paths(slide_number, chap_id)

    categories = {
        "definition" : [],
        "formule"    : formulas,
        "exemple"    : [],
        "remarque"   : [],
        "image"      : image_paths,   # images associées au bon slide
    }

    lines = slide_content.split("\n")
    for line in lines:
        line_lower = line.lower().strip()
        if not line_lower:
            continue
        for category, patterns in CATEGORY_KEYWORDS.items():
            for pattern in patterns:
                if re.search(pattern, line_lower):
                    if category in categories:
                        categories[category].append(line.strip())
                    break

    categories = {k: v for k, v in categories.items() if v}
    return categories



for file in PPT_FILES:

    prs = Presentation(file)

    # Récupération du nom du chapitre depuis la première slide
    first_slide_text = "\n".join(
        shape.text
        for shape in prs.slides[0].shapes
        if shape.has_text_frame
    )

    chap_name = extract_chapter_name(first_slide_text, file)

    print(f"\n========== {file} ==========\n")
    print(f"Chapitre : {chap_name}\n")
    for i, slide in enumerate(prs.slides):
        slide_number = i + 1
        section    = extract_slide_section(slide)
        content    = extract_slide_content(slide, section, slide_number)
        categories = extract_categories(slide, content, slide_number, chap_id=1)
        print(f"Slide {slide_number} categories: {categories}")
        print("------")
# Out:
# ========== ../data/1-ppt\Cours_TS_Chap1.pptx ==========
#
# Chapitre : Représentation temporelle des signaux
#
# Slide 1 categories: {}
# ------
# Slide 2 categories: {}
# ------
# Slide 3 categories: {'image': ['../data/extracted_images\\chapitre1\\slide3_img1.png', '../data/extracted_images\\chapitre1\\slide3_img2.png', '../data/extracted_images\\chapitre1\\slide3_img3.png']}
# ------
# Slide 4 categories: {'formule': [{'formula_id': 3, 'slide': 4, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑗:\xa0𝑗^2=−1', 'raw_itertext': '𝑗:\xa0𝑗2=−1'}, {'formula_id': 4, 'slide': 4, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)=𝑎(𝑡)+𝑗\xa0𝑏(𝑡)', 'raw_itertext': '𝑥𝑡=𝑎𝑡+𝑗\xa0𝑏𝑡'}, {'formula_id': 5, 'slide': 4, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑅𝑒(𝑥(𝑡))=𝑎(𝑡)', 'raw_itertext': '𝑅𝑒𝑥𝑡=𝑎𝑡'}, {'formula_id': 6, 'slide': 4, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝐼𝑚(𝑥(𝑡))=𝑏(𝑡)', 'raw_itertext': '𝐼𝑚𝑥𝑡=𝑏𝑡'}, {'formula_id': 7, 'slide': 4, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '(𝑥(𝑡))=√(𝑎2𝑡+𝑏2𝑡)', 'raw_itertext': '𝑥(𝑡)=𝑎2𝑡+𝑏2𝑡'}, {'formula_id': 8, 'slide': 4, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝐴𝑟𝑔(𝑥(𝑡))=𝑎𝑟𝑐𝑡𝑎𝑛((𝑏(𝑡)/𝑎(𝑡)))', 'raw_itertext': '𝐴𝑟𝑔𝑥𝑡=𝑎𝑟𝑐𝑡𝑎𝑛𝑏(𝑡)𝑎(𝑡)'}, {'formula_id': 9, 'slide': 4, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)=(𝑥(𝑡))𝑒^𝑗𝐴𝑟𝑔𝑥𝑡', 'raw_itertext': '𝑥𝑡=𝑥𝑡𝑒𝑗𝐴𝑟𝑔𝑥𝑡'}, {'formula_id': 10, 'slide': 4, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥^∗(𝑡)=𝑎(𝑡)−𝑗\xa0𝑏(𝑡)=(𝑥(𝑡))𝑒^−𝑗𝐴𝑟𝑔𝑥𝑡', 'raw_itertext': '𝑥∗𝑡=𝑎𝑡−𝑗\xa0𝑏𝑡=𝑥𝑡𝑒−𝑗𝐴𝑟𝑔𝑥𝑡'}]}
# ------
# Slide 5 categories: {'image': ['../data/extracted_images\\chapitre1\\slide5_img4.png', '../data/extracted_images\\chapitre1\\slide5_img5.png', '../data/extracted_images\\chapitre1\\slide5_img6.png']}
# ------
# Slide 6 categories: {'exemple': ['Exemple : le bruit'], 'image': ['../data/extracted_images\\chapitre1\\slide6_img7.png']}
# ------
# Slide 7 categories: {'image': ['../data/extracted_images\\chapitre1\\slide7_img8.png']}
# ------
# Slide 8 categories: {'exemple': ['Exemple : onde électromagnétique, signal électrique, ...', 'Exemple : cours de la bourse enregistré chaque heure, signal']}
# ------
# Slide 9 categories: {'image': ['../data/extracted_images\\chapitre1\\slide9_img9.png']}
# ------
# Slide 10 categories: {'image': ['../data/extracted_images\\chapitre1\\slide10_img10.png', '../data/extracted_images\\chapitre1\\slide10_img11.png']}
# ------
# Slide 11 categories: {'image': ['../data/extracted_images\\chapitre1\\slide11_img12.png']}
# ------
# Slide 12 categories: {'image': ['../data/extracted_images\\chapitre1\\slide12_img13.png']}
# ------
# Slide 13 categories: {'definition': ['Support temporel: On appelle support temporel, l’ensemble des temps [EQ: 𝑡] (ou des échantillons [EQ: 𝑛] si le signal est discret) pour lesquels le signal [EQ: 𝑥(𝑡)\xa0](resp. [EQ: 𝑥_𝑛\xa0]) est défini et non nul.'], 'remarque': ['Remarque : Dans la pratique, tous les signaux physiques observés sont à support fini ou à support borné.']}
# ------
# Slide 14 categories: {'definition': ['Puissance instantanée:  Etant donné un signal continu x(t), on appelle puissance instantanée la quantité |x(t)|2'], 'image': ['../data/extracted_images\\chapitre1\\slide14_img14.png']}
# ------
# Slide 15 categories: {'formule': [{'formula_id': 1, 'slide': 15, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝐸_𝑥=−∞+∞𝑥(𝑡)^2𝑑𝑡', 'raw_itertext': '𝐸𝑥=−∞+∞𝑥(𝑡)2𝑑𝑡'}], 'image': ['../data/extracted_images\\chapitre1\\slide15_img15.png']}
# ------
# Slide 16 categories: {'formule': [{'formula_id': 1, 'slide': 16, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑃_𝑥=lim𝑇→+∞\xa0\xa0\xa0(1/𝑇)−(𝑇/2)+(𝑇/2)𝑥(𝑡)^2𝑑𝑡', 'raw_itertext': '𝑃𝑥=lim𝑇→+∞\xa0\xa0\xa01𝑇−𝑇2+𝑇2𝑥(𝑡)2𝑑𝑡'}]}
# ------
# Slide 17 categories: {'remarque': ['En pratique, c’est le cas de tous les signaux physiquement réalisables.']}
# ------
# Slide 18 categories: {'formule': [{'formula_id': 1, 'slide': 18, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)=𝑥(𝑡+𝑘\xa0𝑇_0),\xa0𝑘∈\xa0ℤ', 'raw_itertext': '𝑥𝑡=𝑥𝑡+𝑘\xa0𝑇0,\xa0𝑘∈\xa0ℤ'}, {'formula_id': 2, 'slide': 18, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)=sin(2\xa0𝜋\xa0𝑓_0𝑡)', 'raw_itertext': '𝑥𝑡=sin2\xa0𝜋\xa0𝑓0𝑡'}, {'formula_id': 3, 'slide': 18, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑇_0=(1/𝑓0)', 'raw_itertext': '𝑇0=1𝑓0'}], 'exemple': ['Exemple de signaux périodiques:  sinus et cosinus'], 'image': ['../data/extracted_images\\chapitre1\\slide18_img16.png']}
# ------
# Slide 19 categories: {'definition': ['Etant donné un signal périodique, on appelle période fondamentale et on note  [EQ: 𝑇_0], la plus petite période du signal strictement positive:'], 'remarque': ['Etant donné un signal périodique, on appelle période fondamentale et on note  [EQ: 𝑇_0], la plus petite période du signal strictement positive:'], 'image': ['../data/extracted_images\\chapitre1\\slide19_img17.png']}
# ------
# Slide 20 categories: {'formule': [{'formula_id': 3, 'slide': 20, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑃_𝑥=\xa0\xa0\xa0(1/𝑇0)0𝑇_0𝑥(𝑡)^2𝑑𝑡', 'raw_itertext': '𝑃𝑥=\xa0\xa0\xa01𝑇00𝑇0𝑥(𝑡)2𝑑𝑡'}]}
# ------
# Slide 21 categories: {'formule': [{'formula_id': 1, 'slide': 21, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)=𝑡', 'raw_itertext': '𝑥𝑡=𝑡'}], 'image': ['../data/extracted_images\\chapitre1\\slide21_img18.png', '../data/extracted_images\\chapitre1\\slide21_img19.png']}
# ------
# Slide 22 categories: {'formule': [{'formula_id': 2, 'slide': 22, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)=0,\xa0∀\xa0𝑡<0', 'raw_itertext': '𝑥𝑡=0,\xa0∀\xa0𝑡<0'}], 'image': ['../data/extracted_images\\chapitre1\\slide22_img20.png', '../data/extracted_images\\chapitre1\\slide22_img21.png', '../data/extracted_images\\chapitre1\\slide22_img22.png', '../data/extracted_images\\chapitre1\\slide22_img23.png']}
# ------
# Slide 23 categories: {'formule': [{'formula_id': 2, 'slide': 23, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)=𝑥(−𝑡)', 'raw_itertext': '𝑥𝑡=𝑥(−𝑡)'}, {'formula_id': 4, 'slide': 23, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)=−𝑥(−𝑡)', 'raw_itertext': '𝑥𝑡=−𝑥(−𝑡)'}], 'image': ['../data/extracted_images\\chapitre1\\slide23_img24.png', '../data/extracted_images\\chapitre1\\slide23_img25.png']}
# ------
# Slide 24 categories: {'image': ['../data/extracted_images\\chapitre1\\slide24_img26.png', '../data/extracted_images\\chapitre1\\slide24_img27.png']}
# ------
# Slide 25 categories: {'image': ['../data/extracted_images\\chapitre1\\slide25_img28.png']}
# ------
# Slide 26 categories: {'image': ['../data/extracted_images\\chapitre1\\slide26_img29.png']}
# ------
# Slide 27 categories: {'exemple': ['Illustration: https://vincmazet.github.io/spetsi/dilatation.html'], 'image': ['../data/extracted_images\\chapitre1\\slide27_img30.png']}
# ------
# Slide 28 categories: {'exemple': ['Illustration: https://vincmazet.github.io/spetsi/dilatation.html'], 'image': ['../data/extracted_images\\chapitre1\\slide28_img31.png']}
# ------
# Slide 29 categories: {'exemple': ['Illustration: https://vincmazet.github.io/spetsi/sinus.html'], 'image': ['../data/extracted_images\\chapitre1\\slide29_img32.png', '../data/extracted_images\\chapitre1\\slide29_img33.png']}
# ------
# Slide 30 categories: {'formule': [{'formula_id': 1, 'slide': 30, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑠𝑖𝑛𝑐(𝑡)=(\xa01\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0si\xa0𝑡=0(sin𝜋𝑡/𝜋𝑡)\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0sinon)', 'raw_itertext': '𝑠𝑖𝑛𝑐𝑡=\xa01\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0si\xa0𝑡=0sin𝜋𝑡𝜋𝑡\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0sinon'}], 'image': ['../data/extracted_images\\chapitre1\\slide30_img34.png']}
# ------
# Slide 31 categories: {'formule': [{'formula_id': 1, 'slide': 31, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑟𝑒𝑐𝑡_𝑇(𝑡)=(1\xa0\xa0\xa0\xa0si\xa0(−𝑇/2)≤𝑡\xa0≤(𝑇/2)0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0sinon)', 'raw_itertext': '𝑟𝑒𝑐𝑡𝑇𝑡=1\xa0\xa0\xa0\xa0si\xa0−𝑇2≤𝑡\xa0≤𝑇20\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0sinon'}], 'image': ['../data/extracted_images\\chapitre1\\slide31_img35.png']}
# ------
# Slide 32 categories: {'image': ['../data/extracted_images\\chapitre1\\slide32_img36.png']}
# ------
# Slide 33 categories: {'formule': [{'formula_id': 1, 'slide': 33, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 't𝑟𝑖(𝑡)=(1−\xa0(𝑡)\xa0\xa0pour\xa0\xa0\xa0(𝑡)≤10\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0pour\xa0\xa0\xa0(𝑡)>1)', 'raw_itertext': 't𝑟𝑖𝑡=1−\xa0𝑡\xa0\xa0pour\xa0\xa0\xa0𝑡≤10\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0pour\xa0\xa0\xa0𝑡>1'}], 'image': ['../data/extracted_images\\chapitre1\\slide33_img37.png']}
# ------
# Slide 34 categories: {'formule': [{'formula_id': 1, 'slide': 34, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 'Γ(𝑡)=(0\xa0\xa0\xa0\xa0pour\xa0\xa0\xa0𝑡<01\xa0\xa0\xa0\xa0pour\xa0\xa0\xa0𝑡≥0)', 'raw_itertext': 'Γ𝑡=0\xa0\xa0\xa0\xa0pour\xa0\xa0\xa0𝑡<01\xa0\xa0\xa0\xa0pour\xa0\xa0\xa0𝑡≥0'}, {'formula_id': 2, 'slide': 34, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 'Γ(𝑡)=1', 'raw_itertext': 'Γ𝑡=1'}], 'image': ['../data/extracted_images\\chapitre1\\slide34_img38.png']}
# ------
# Slide 35 categories: {'formule': [{'formula_id': 1, 'slide': 35, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑠𝑔𝑛(𝑡)=(−1\xa0\xa0\xa0\xa0pour\xa0\xa0\xa0𝑡<01\xa0\xa0\xa0\xa0pour\xa0\xa0\xa0𝑡≥0)', 'raw_itertext': '𝑠𝑔𝑛𝑡=−1\xa0\xa0\xa0\xa0pour\xa0\xa0\xa0𝑡<01\xa0\xa0\xa0\xa0pour\xa0\xa0\xa0𝑡≥0'}, {'formula_id': 2, 'slide': 35, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑠𝑔𝑛(𝑡)=1', 'raw_itertext': '𝑠𝑔𝑛𝑡=1'}, {'formula_id': 3, 'slide': 35, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 't=0', 'raw_itertext': 't=0'}], 'image': ['../data/extracted_images\\chapitre1\\slide35_img39.png']}
# ------
# Slide 36 categories: {'formule': [{'formula_id': 1, 'slide': 36, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝛿(𝑡)=(0\xa0pour\xa0\xa0\xa0𝑡≠0\xa0+∞\xa0\xa0pour\xa0\xa0\xa0𝑡=0)', 'raw_itertext': '𝛿𝑡=0\xa0pour\xa0\xa0\xa0𝑡≠0\xa0+∞\xa0\xa0pour\xa0\xa0\xa0𝑡=0'}], 'remarque': ['Attention: le 1 marqué sur la flèche représente l’aire de cette impulsion et non l’hauteur de l’impulsion'], 'image': ['../data/extracted_images\\chapitre1\\slide36_img40.png', '../data/extracted_images\\chapitre1\\slide36_img41.png']}
# ------
# Slide 37 categories: {'formule': [{'formula_id': 1, 'slide': 37, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '∞+∞𝛿(𝑡)𝑑𝑡=1', 'raw_itertext': '∞+∞𝛿𝑡𝑑𝑡=1'}, {'formula_id': 2, 'slide': 37, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝛿(𝑡)=0,\xa0\xa0\xa0\xa0\xa0∀\xa0𝑡\xa0≠0', 'raw_itertext': '𝛿𝑡=0,\xa0\xa0\xa0\xa0\xa0∀\xa0𝑡\xa0≠0'}, {'formula_id': 3, 'slide': 37, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡).𝛿(𝑡)=𝑥(0).𝛿(𝑡)', 'raw_itertext': '𝑥𝑡.𝛿𝑡=𝑥0.𝛿𝑡'}, {'formula_id': 4, 'slide': 37, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '∞+∞𝑥(𝑡)𝛿(𝑡)𝑑𝑡=𝑥(0))', 'raw_itertext': '∞+∞𝑥(𝑡)𝛿𝑡𝑑𝑡=𝑥(0))'}]}
# ------
# Slide 38 categories: {'formule': [{'formula_id': 1, 'slide': 38, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝛿(𝑡)=lim𝑇→0(1/𝑇)𝑟𝑒𝑐𝑡_𝑇(𝑡)', 'raw_itertext': '𝛿(𝑡)=lim𝑇→01𝑇𝑟𝑒𝑐𝑡𝑇(𝑡)'}, {'formula_id': 3, 'slide': 38, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝛿(𝑡)=(𝑑Γ(𝑡)/𝑑𝑡)', 'raw_itertext': '𝛿𝑡=𝑑Γ(𝑡)𝑑𝑡'}], 'exemple': ['Illustration: https://vincmazet.github.io/spetsi/limite-dirac.html'], 'remarque': ['Remarque 1: l’Impulsion de Dirac peut être vue comme une fonction porte dont la largeur T tendrait vers 0 et dont l’aire est égale à 1', 'Remarque 2: : On peut considérer [EQ: 𝛿(𝑡)\xa0]comme la dérivée de la fonction échelon']}
# ------
# Slide 39 categories: {'formule': [{'formula_id': 7, 'slide': 39, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '−∞+∞𝛿(𝑡−𝑡_0)dt=1', 'raw_itertext': '−∞+∞𝛿(𝑡−𝑡0)dt=1'}, {'formula_id': 8, 'slide': 39, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝛿(𝑡−𝑡_0)=0\xa0\xa0\xa0\xa0\xa0∀\xa0𝑡\xa0≠𝑡_0', 'raw_itertext': '𝛿𝑡−𝑡0=0\xa0\xa0\xa0\xa0\xa0∀\xa0𝑡\xa0≠𝑡0'}, {'formula_id': 9, 'slide': 39, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)𝛿(𝑡−𝑡_0)=𝑥(𝑡_0)𝛿(𝑡−𝑡_0)', 'raw_itertext': '𝑥(𝑡)𝛿𝑡−𝑡0=𝑥(𝑡0)𝛿𝑡−𝑡0'}], 'image': ['../data/extracted_images\\chapitre1\\slide39_img42.png']}
# ------
# Slide 40 categories: {'definition': ['On appelle peigne de Dirac une somme infinie d’impulsions de Dirac régulièrement espacées de  [EQ: 𝑇] . Elle est définie par :'], 'formule': [{'formula_id': 2, 'slide': 40, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 'Ш_𝑇(𝑡)=𝑘=−∞+∞𝛿(𝑡−𝑘𝑇)', 'raw_itertext': 'Ш𝑇𝑡=𝑘=−∞+∞𝛿𝑡−𝑘𝑇'}], 'image': ['../data/extracted_images\\chapitre1\\slide40_img43.png']}
# ------
# Slide 41 categories: {'formule': [{'formula_id': 1, 'slide': 41, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑓𝑡.\xa0Ш_T(𝑡)=𝑘=−∞+∞𝑓(𝑘𝑇)\xa0\xa0𝛿(𝑡−𝑘𝑇)', 'raw_itertext': '𝑓𝑡.\xa0ШT𝑡=𝑘=−∞+∞𝑓𝑘𝑇\xa0\xa0𝛿(𝑡−𝑘𝑇)'}], 'image': ['../data/extracted_images\\chapitre1\\slide41_img44.png']}
# ------
# Slide 42 categories: {}
# ------
# Slide 43 categories: {'image': ['../data/extracted_images\\chapitre1\\slide43_img45.png']}
# ------
# Slide 44 categories: {'image': ['../data/extracted_images\\chapitre1\\slide44_img46.png']}
# ------
#
# ========== ../data/1-ppt\Cours_TS_Chap2.pptx ==========
#
# Chapitre : Systèmes linéaires continus
#
# Slide 1 categories: {}
# ------
# Slide 2 categories: {}
# ------
# Slide 3 categories: {'image': ['../data/extracted_images\\chapitre1\\slide3_img1.png', '../data/extracted_images\\chapitre1\\slide3_img2.png', '../data/extracted_images\\chapitre1\\slide3_img3.png']}
# ------
# Slide 4 categories: {}
# ------
# Slide 5 categories: {'image': ['../data/extracted_images\\chapitre1\\slide5_img4.png', '../data/extracted_images\\chapitre1\\slide5_img5.png', '../data/extracted_images\\chapitre1\\slide5_img6.png']}
# ------
# Slide 6 categories: {'formule': [{'formula_id': 1, 'slide': 6, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 'i\xa0𝑥(𝑡)=𝑎_1𝑥_1(𝑡)+𝑎_2𝑥_2(𝑡)', 'raw_itertext': 'i\xa0𝑥𝑡=𝑎1𝑥1(𝑡)+𝑎2𝑥2(𝑡)'}, {'formula_id': 2, 'slide': 6, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑦(𝑡)=𝑎_1𝑆(𝑥_1(𝑡))+𝑎_2𝑆(𝑥_2(𝑡))', 'raw_itertext': '𝑦𝑡=𝑎1𝑆𝑥1(𝑡)+𝑎2𝑆𝑥2(𝑡)'}], 'image': ['../data/extracted_images\\chapitre1\\slide6_img7.png']}
# ------
# Slide 7 categories: {'formule': [{'formula_id': 1, 'slide': 7, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)=0', 'raw_itertext': '𝑥𝑡=0'}, {'formula_id': 3, 'slide': 7, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 'y(𝑡)=𝑆(𝑥(𝑡))=0', 'raw_itertext': 'y𝑡=𝑆𝑥(𝑡)=0'}], 'image': ['../data/extracted_images\\chapitre1\\slide7_img8.png']}
# ------
# Slide 8 categories: {'formule': [{'formula_id': 1, 'slide': 8, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 'y(𝑡)=𝑆(𝑥(𝑡))', 'raw_itertext': 'y𝑡=𝑆𝑥(𝑡)'}, {'formula_id': 2, 'slide': 8, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 'y(𝑡−𝑡_0)=𝑆(𝑥(𝑡−𝑡_0))', 'raw_itertext': 'y𝑡−𝑡0=𝑆𝑥(𝑡−𝑡0)'}]}
# ------
# Slide 9 categories: {'formule': [{'formula_id': 1, 'slide': 9, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '∃(\xa0\xa0𝑀𝑥/\xa0\xa0𝑥(𝑡)<𝑀𝑥\xa0\xa0⇒∃\xa0\xa0\xa0𝑀𝑦\xa0\xa0y𝑡=𝑆𝑥(𝑡)<𝑀𝑦\xa0\xa0)', 'raw_itertext': '∃\xa0\xa0𝑀𝑥\xa0\xa0𝑥(𝑡)<𝑀𝑥\xa0\xa0⇒∃\xa0\xa0\xa0𝑀𝑦\xa0\xa0y𝑡=𝑆𝑥(𝑡)<𝑀𝑦'}], 'image': ['../data/extracted_images\\chapitre1\\slide9_img9.png']}
# ------
# Slide 10 categories: {'exemple': ['Exemple de système'], 'image': ['../data/extracted_images\\chapitre1\\slide10_img10.png', '../data/extracted_images\\chapitre1\\slide10_img11.png']}
# ------
# Slide 11 categories: {'image': ['../data/extracted_images\\chapitre1\\slide11_img12.png']}
# ------
# Slide 12 categories: {'image': ['../data/extracted_images\\chapitre1\\slide12_img13.png']}
# ------
# Slide 13 categories: {}
# ------
# Slide 14 categories: {'image': ['../data/extracted_images\\chapitre1\\slide14_img14.png']}
# ------
# Slide 15 categories: {'exemple': ['Exemple de système variant temporellement'], 'image': ['../data/extracted_images\\chapitre1\\slide15_img15.png']}
# ------
# Slide 16 categories: {'exemple': ['Exemple de système variant temporellement']}
# ------
# Slide 17 categories: {}
# ------
# Slide 18 categories: {'exemple': ['Exemple:'], 'image': ['../data/extracted_images\\chapitre1\\slide18_img16.png']}
# ------
# Slide 19 categories: {'image': ['../data/extracted_images\\chapitre1\\slide19_img17.png']}
# ------
# Slide 20 categories: {}
# ------
# Slide 21 categories: {'image': ['../data/extracted_images\\chapitre1\\slide21_img18.png', '../data/extracted_images\\chapitre1\\slide21_img19.png']}
# ------
# Slide 22 categories: {'definition': ['On appelle   Produit de convolution  de deux signaux [EQ: 𝑥(𝑡)] et [EQ: 𝑦(𝑡)], et on note [EQ: \xa0\xa0\xa0𝑥(𝑡)∗𝑦(𝑡)] l’expression:'], 'formule': [{'formula_id': 4, 'slide': 22, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑧(𝑡)=𝑥(𝑡)∗𝑦(𝑡)=−∞+∞𝑥(𝜏)\xa0\xa0𝑦(𝑡−𝜏)𝑑𝜏', 'raw_itertext': '𝑧𝑡=𝑥𝑡∗𝑦𝑡=−∞+∞𝑥𝜏\xa0\xa0𝑦𝑡−𝜏𝑑𝜏'}, {'formula_id': 5, 'slide': 22, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)=0,\xa0\xa0𝑦(𝑡)=0\xa0pour\xa0𝑡\xa0<0', 'raw_itertext': '𝑥𝑡=0,\xa0\xa0𝑦𝑡=0\xa0pour\xa0𝑡\xa0<0'}, {'formula_id': 6, 'slide': 22, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑧(𝑡)=𝑥(𝑡)∗𝑦(𝑡)=0+∞𝑥(𝜏)\xa0\xa0𝑦(𝑡−𝜏)𝑑𝜏', 'raw_itertext': '𝑧𝑡=𝑥𝑡∗𝑦𝑡=0+∞𝑥𝜏\xa0\xa0𝑦𝑡−𝜏𝑑𝜏'}], 'remarque': ['On appelle   Produit de convolution  de deux signaux [EQ: 𝑥(𝑡)] et [EQ: 𝑦(𝑡)], et on note [EQ: \xa0\xa0\xa0𝑥(𝑡)∗𝑦(𝑡)] l’expression:'], 'image': ['../data/extracted_images\\chapitre1\\slide22_img20.png', '../data/extracted_images\\chapitre1\\slide22_img21.png', '../data/extracted_images\\chapitre1\\slide22_img22.png', '../data/extracted_images\\chapitre1\\slide22_img23.png']}
# ------
# Slide 23 categories: {'exemple': ['Illustration: https://vincmazet.github.io/spetsi/conv1c.html'], 'image': ['../data/extracted_images\\chapitre1\\slide23_img24.png', '../data/extracted_images\\chapitre1\\slide23_img25.png']}
# ------
# Slide 24 categories: {'image': ['../data/extracted_images\\chapitre1\\slide24_img26.png', '../data/extracted_images\\chapitre1\\slide24_img27.png']}
# ------
# Slide 25 categories: {'image': ['../data/extracted_images\\chapitre1\\slide25_img28.png']}
# ------
# Slide 26 categories: {'image': ['../data/extracted_images\\chapitre1\\slide26_img29.png']}
# ------
# Slide 27 categories: {'formule': [{'formula_id': 1, 'slide': 27, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)∗𝑦(𝑡)=𝑦(𝑡)∗𝑥(𝑡)', 'raw_itertext': '𝑥𝑡∗𝑦𝑡=𝑦𝑡∗𝑥(𝑡)'}, {'formula_id': 2, 'slide': 27, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)∗𝑦(𝑡)∗𝑧(𝑡)=𝑥(𝑡)∗(𝑦(𝑡)∗𝑧(𝑡))=[𝑥(𝑡)∗𝑦(𝑡)]∗𝑧(𝑡)', 'raw_itertext': '𝑥𝑡∗𝑦𝑡∗𝑧𝑡=𝑥𝑡∗𝑦𝑡∗𝑧𝑡=[𝑥𝑡∗𝑦𝑡]∗𝑧𝑡'}, {'formula_id': 3, 'slide': 27, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)∗(𝑦(𝑡)+𝑧(𝑡))=𝑥(𝑡)∗𝑦(𝑡)+𝑥(𝑡)∗𝑧(𝑡)', 'raw_itertext': '𝑥𝑡∗𝑦𝑡+𝑧𝑡=𝑥𝑡∗𝑦𝑡+𝑥𝑡∗𝑧(𝑡)'}, {'formula_id': 4, 'slide': 27, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)∗𝛿(𝑡)=𝑥(𝑡)', 'raw_itertext': '𝑥𝑡∗𝛿𝑡=𝑥𝑡'}, {'formula_id': 5, 'slide': 27, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)∗𝛿(𝑡−𝑡_0)=𝑥(𝑡−𝑡_0)', 'raw_itertext': '𝑥𝑡∗𝛿𝑡−𝑡0=𝑥𝑡−𝑡0'}], 'image': ['../data/extracted_images\\chapitre1\\slide27_img30.png']}
# ------
# Slide 28 categories: {'formule': [{'formula_id': 1, 'slide': 28, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 'Ш_𝑇(𝑡)=𝑘=−∞+∞𝛿(𝑡−𝑘𝑇)', 'raw_itertext': 'Ш𝑇𝑡=𝑘=−∞+∞𝛿(𝑡−𝑘𝑇)'}, {'formula_id': 3, 'slide': 28, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 'Ш_𝑇(𝑡)=', 'raw_itertext': 'Ш𝑇𝑡='}, {'formula_id': 4, 'slide': 28, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑘=−∞+∞𝑓(𝑡)∗𝛿(𝑡−𝑘𝑇)', 'raw_itertext': '𝑘=−∞+∞𝑓(𝑡)∗𝛿(𝑡−𝑘𝑇)'}, {'formula_id': 6, 'slide': 28, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑓(𝑡)∗\xa0Ш_𝑇(𝑡)=\xa0𝑘=−∞+∞𝑓(𝑡−𝑘𝑇)', 'raw_itertext': '𝑓(𝑡)∗\xa0Ш𝑇𝑡=\xa0𝑘=−∞+∞𝑓(𝑡−𝑘𝑇)'}], 'image': ['../data/extracted_images\\chapitre1\\slide28_img31.png']}
# ------
# Slide 29 categories: {'exemple': ['Application de la notion de convolution'], 'image': ['../data/extracted_images\\chapitre1\\slide29_img32.png', '../data/extracted_images\\chapitre1\\slide29_img33.png']}
# ------
# Slide 30 categories: {'formule': [{'formula_id': 1, 'slide': 30, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑥(𝑡)=𝑥(𝑡)∗𝛿(𝑡)⟹𝑥(𝑡)=−∞+∞𝑥(𝜏)\xa0\xa0𝛿(𝑡−𝜏)𝑑𝜏', 'raw_itertext': '𝑥𝑡=𝑥𝑡∗𝛿𝑡⟹𝑥𝑡=−∞+∞𝑥𝜏\xa0\xa0𝛿𝑡−𝜏𝑑𝜏'}, {'formula_id': 3, 'slide': 30, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑦(𝑡)=𝑆(𝑥(𝑡))', 'raw_itertext': '𝑦𝑡=𝑆𝑥𝑡'}, {'formula_id': 4, 'slide': 30, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '⟹𝑦(𝑡)=𝑆(−∞+∞𝑥(𝜏)\xa0\xa0𝛿(𝑡−𝜏)𝑑𝜏)', 'raw_itertext': '⟹𝑦𝑡=𝑆−∞+∞𝑥𝜏\xa0\xa0𝛿𝑡−𝜏𝑑𝜏'}, {'formula_id': 5, 'slide': 30, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑦(𝑡)=−∞+∞𝑥(𝜏)\xa0\xa0𝑆[𝛿(𝑡−𝜏)]𝑑𝜏', 'raw_itertext': '𝑦𝑡=−∞+∞𝑥𝜏\xa0\xa0𝑆[𝛿𝑡−𝜏]𝑑𝜏'}, {'formula_id': 6, 'slide': 30, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑆(𝛿(𝑡))=ℎ(𝑡)', 'raw_itertext': '𝑆𝛿𝑡=ℎ(𝑡)'}, {'formula_id': 7, 'slide': 30, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑆(𝛿(𝑡−𝜏))=ℎ(𝑡−𝜏)', 'raw_itertext': '𝑆𝛿𝑡−𝜏=ℎ(𝑡−𝜏)'}], 'exemple': ['Application de la notion de convolution'], 'image': ['../data/extracted_images\\chapitre1\\slide30_img34.png']}
# ------
# Slide 31 categories: {'formule': [{'formula_id': 1, 'slide': 31, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑦(𝑡)=−∞+∞𝑥(𝜏)\xa0\xa0ℎ(𝑡−𝜏)𝑑𝜏', 'raw_itertext': '𝑦𝑡=−∞+∞𝑥𝜏\xa0\xa0ℎ𝑡−𝜏𝑑𝜏'}, {'formula_id': 3, 'slide': 31, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': '𝑦(𝑡)=𝑥(𝑡)∗ℎ(𝑡)', 'raw_itertext': '𝑦𝑡=𝑥(𝑡)∗ℎ(𝑡)'}], 'image': ['../data/extracted_images\\chapitre1\\slide31_img35.png']}
# ------
# Slide 32 categories: {'image': ['../data/extracted_images\\chapitre1\\slide32_img36.png']}
# ------
# Slide 33 categories: {'formule': [{'formula_id': 1, 'slide': 33, 'shape_name': 'AlternateContent', 'type': 'OMML', 'extractable': True, 'text': 'ℎ(𝑡)=𝑂\xa0,\xa0\xa0\xa0\xa0\xa0\xa0∀\xa0𝑡<𝑂', 'raw_itertext': 'ℎ𝑡=𝑂\xa0,\xa0\xa0\xa0\xa0\xa0\xa0∀\xa0𝑡<𝑂'}], 'image': ['../data/extracted_images\\chapitre1\\slide33_img37.png']}
# ------

# %% [markdown]
# # Extraction des images
# La partie suivante nous permet de  extraire les images du cours .

# %%
from pptx import Presentation
import os

# Dossier racine des images
output_dir = "../data/extracted_images"
os.makedirs(output_dir, exist_ok=True)

total_images = 0

for chap_idx, ppt_path in enumerate(PPT_FILES, start=1):

    prs = Presentation(ppt_path)
    image_count = 0

    # Sous-dossier du chapitre
    chap_dir = os.path.join(output_dir, f"chapitre{chap_idx}")
    os.makedirs(chap_dir, exist_ok=True)

    for slide_index, slide in enumerate(prs.slides):

        for shape in slide.shapes:

            # 13 = Picture
            if shape.shape_type == 13:

                image = shape.image
                image_bytes = image.blob
                ext = "." + image.ext

                image_count += 1

                # Nom de l'image
                image_filename = (
                    f"slide{slide_index+1}_img{image_count}{ext}"
                )

                image_path = os.path.join(chap_dir, image_filename)

                with open(image_path, "wb") as f:
                    f.write(image_bytes)

    total_images += image_count

    print(
        f"Chapitre {chap_idx} "
        f"({os.path.basename(ppt_path)}) : "
        f"{image_count} image(s) extraite(s)"
    )

print(f"\nTotal : {total_images} image(s) extraite(s)")
print(f"Dossier de sortie : {output_dir}/")
# Out:
# Chapitre 1 (Cours_TS_Chap1.pptx) : 46 image(s) extraite(s)
# Chapitre 2 (Cours_TS_Chap2.pptx) : 52 image(s) extraite(s)
#
# Total : 98 image(s) extraite(s)
# Dossier de sortie : ../data/extracted_images/

# %% [markdown]
# ### Main : structuration des données et sauvegarde JSON
# Finalement, on parcours les slides du ppt et on affecte à chacune son **id, section(titre), notions, catégories et contenu** en faisant appel au fonctions déjà définies.

# %%
from pptx import Presentation

# Reinitialisation du cours
course["chapters"]    = []
course["course_plan"] = [{"chap_id": 0, "chap_name": "Introduction"}]

# Boucle sur tous les fichiers .pptx
for chap_idx, ppt_path in enumerate(PPT_FILES, start=1):
    prs = Presentation(ppt_path)

    # Nom du chapitre extrait de la premiere slide
    first_slide_text = "\n".join(
        shape.text for shape in prs.slides[0].shapes if shape.has_text_frame
    )
    chap_name = extract_chapter_name(first_slide_text, ppt_path)

    chapter = {
        "chap_id"  : chap_idx,
        "chap_name": chap_name,
        "content"  : []
    }

    # Mise a jour du plan du cours
    course["course_plan"].append({"chap_id": chap_idx, "chap_name": chap_name})

    print(f"\n{'='*60}")
    print(f"Chapitre {chap_idx} : {chap_name}")
    print(f"Fichier  : {os.path.basename(ppt_path)}")
    print(f"{'='*60}")

    # Traitement des slides (on saute la slide de titre, index 0)
    for i, slide in enumerate(prs.slides):
        if i == 0:  # slide de titre -> deja utilisee pour chap_name
            continue

        slide_number = i + 1

        section    = extract_slide_section(slide)
        content    = extract_slide_content(slide, section, slide_number)
        notions    = extract_notions(chap_name, section, content)
        categories = extract_categories(slide, content, slide_number, chap_id=chap_idx)

        slide_dict = {
            "slide_id"     : slide_number,
            "section"      : section,
            "categories"   : categories,
            "notions"      : notions,
            "slide_content": content
        }
        chapter["content"].append(slide_dict)

    course["chapters"].append(chapter)
    print(f"  -> {len(chapter['content'])} slide(s) traite(s)")

# Resume final
print(f"\n{'='*60}")
print(f"Cours : {course['course_name']}")
print(f"Plan  : {len(course['course_plan'])} chapitre(s) (dont Introduction)")
print(f"{'='*60}")
pprint(course["course_plan"])
# Out:
# ============================================================
# Chapitre 1 : Représentation temporelle des signaux
# Fichier  : Cours_TS_Chap1.pptx
# ============================================================
#   -> 43 slide(s) traite(s)
#
# ============================================================
# Chapitre 2 : Systèmes linéaires continus
# Fichier  : Cours_TS_Chap2.pptx
# ============================================================
#   -> 32 slide(s) traite(s)
#
# ============================================================
# Cours : Traitement du signal
# Plan  : 3 chapitre(s) (dont Introduction)
# ============================================================
# [{'chap_id': 0, 'chap_name': 'Introduction'},
#  {'chap_id': 1, 'chap_name': 'Représentation temporelle des signaux'},
#  {'chap_id': 2, 'chap_name': 'Systèmes linéaires continus'}]

# %% [markdown]
# Pour terminer, on **sauvegarde** le résultat final en **JSON** :

# %%
import json
import os

# Créer le dossier de sortie si nécessaire
os.makedirs("../data/2-json", exist_ok=True)

JSON_PATH = "../data/2-json/cours.json"

with open(JSON_PATH, "w", encoding="utf-8") as f:
    json.dump(course, f, indent=4, ensure_ascii=False, default=str)

print(f"JSON sauvegardé avec succès → {JSON_PATH}")
# Out:
# JSON sauvegardé avec succès → ../data/2-json/cours.json

# %% [markdown]
# Pour charger le JSON :

# %%
with open("../data/2-json/cours.json", "r", encoding="utf-8") as f:
    course_loaded = json.load(f)
#pprint(course_loaded)
